# %%
# For managing COCO dataset
# from pycocotools.coco import COCO

# For creating and managing folder/ files
import glob
import os
import shutil

# For managing images
from PIL import Image
import skimage.io as io

# Basic libraries
import numpy as np
import pandas as pd
import random
import cv2

# For plotting
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
# import wandb

# For importing models and working with them
## Torch
import torch
import torch.utils.data # for Dataset
import torch.nn as nn
from torch.optim import Adam
from torch.autograd import Variable
from torch.utils.data import DataLoader, Dataset
# import segmentation_models_pytorch as smp

## Torchvision
import torchvision
from torchvision.transforms import transforms

# For creating train - test splits
from sklearn.model_selection import train_test_split

import pathlib
import pylab
import requests
from io import BytesIO
from pprint import pprint
from tqdm import tqdm
import time
from imutils import paths

# Performance Metrics
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import confusion_matrix




device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir Dataset
# !mkdir Dataset/findit

# !unzip /content/drive/MyDrive/findit2.zip -d /content/Dataset/findit
# Out:
# Archive:  /content/drive/MyDrive/findit2.zip
#    creating: /content/Dataset/findit/findit2/
#   inflating: /content/Dataset/findit/__MACOSX/._findit2
#    creating: /content/Dataset/findit/findit2/test/
#   inflating: /content/Dataset/findit/__MACOSX/findit2/._test
#   inflating: /content/Dataset/findit/findit2/train.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/._train.txt
#    creating: /content/Dataset/findit/findit2/train/
#   inflating: /content/Dataset/findit/__MACOSX/findit2/._train
#   inflating: /content/Dataset/findit/findit2/test.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/._test.txt
#   inflating: /content/Dataset/findit/findit2/val.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/._val.txt
#    creating: /content/Dataset/findit/findit2/val/
#   inflating: /content/Dataset/findit/__MACOSX/findit2/._val
#   inflating: /content/Dataset/findit/findit2/test/X51007339127.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007339127.png
#   inflating: /content/Dataset/findit/findit2/test/X51006557117.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006557117.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005568884.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005568884.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006913023.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006913023.png
#   inflating: /content/Dataset/findit/findit2/test/X51006401723.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006401723.png
#   inflating: /content/Dataset/findit/findit2/test/X51006350737.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006350737.png
#   inflating: /content/Dataset/findit/findit2/test/X51005806685.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005806685.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006557507.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006557507.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006620190.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006620190.png
#   inflating: /content/Dataset/findit/findit2/test/X51005577191.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005577191.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005676545.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005676545.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006619507.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006619507.png
#   inflating: /content/Dataset/findit/findit2/test/X51005447839.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005447839.png
#   inflating: /content/Dataset/findit/findit2/test/X51005685355.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005685355.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006329183.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006329183.png
#   inflating: /content/Dataset/findit/findit2/test/X51005676544.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005676544.txt
#   inflating: /content/Dataset/findit/findit2/test/X51008114266.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008114266.png
#   inflating: /content/Dataset/findit/findit2/test/X51006556726.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556726.png
#   inflating: /content/Dataset/findit/findit2/test/X51008042791.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008042791.png
#   inflating: /content/Dataset/findit/findit2/test/X51006620191.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006620191.png
#   inflating: /content/Dataset/findit/findit2/test/X51005745213.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005745213.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006556591.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556591.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005605286.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005605286.png
#   inflating: /content/Dataset/findit/findit2/test/X51006555818.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006555818.png
#   inflating: /content/Dataset/findit/findit2/test/X51007339132.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007339132.png
#   inflating: /content/Dataset/findit/findit2/test/X51007339642.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007339642.png
#   inflating: /content/Dataset/findit/findit2/test/X51008145505.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008145505.txt
#   inflating: /content/Dataset/findit/findit2/test/X51007339118.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007339118.png
#   inflating: /content/Dataset/findit/findit2/test/X51006619764.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006619764.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006556650.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556650.png
#   inflating: /content/Dataset/findit/findit2/test/X51005442361.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005442361.png
#   inflating: /content/Dataset/findit/findit2/test/X51006619869.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006619869.png
#   inflating: /content/Dataset/findit/findit2/test/X51005361898.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005361898.png
#   inflating: /content/Dataset/findit/findit2/test/X51008099081.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008099081.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005663277.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005663277.png
#   inflating: /content/Dataset/findit/findit2/test/X51006556829.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556829.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005745298.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005745298.png
#   inflating: /content/Dataset/findit/findit2/test/X51005676546.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005676546.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005577192.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005577192.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006414715.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006414715.png
#   inflating: /content/Dataset/findit/findit2/test/X51005712017.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005712017.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005675099.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005675099.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006713996.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006713996.png
#   inflating: /content/Dataset/findit/findit2/test/X51006828200.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006828200.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006557188.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006557188.png
#   inflating: /content/Dataset/findit/findit2/test/X51006556828.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556828.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006389963.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006389963.txt
#   inflating: /content/Dataset/findit/findit2/test/X51007846357.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007846357.txt
#   inflating: /content/Dataset/findit/findit2/test/X51007846282.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007846282.png
#   inflating: /content/Dataset/findit/findit2/test/X51007103639.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007103639.png
#   inflating: /content/Dataset/findit/findit2/test/X51008099043.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008099043.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006387737.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006387737.png
#   inflating: /content/Dataset/findit/findit2/test/X51006008082.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006008082.png
#   inflating: /content/Dataset/findit/findit2/test/X51008145504.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008145504.txt
#   inflating: /content/Dataset/findit/findit2/test/X51007339125.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007339125.png
#   inflating: /content/Dataset/findit/findit2/test/X51005621482.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005621482.png
#   inflating: /content/Dataset/findit/findit2/test/X51005268275.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005268275.png
#   inflating: /content/Dataset/findit/findit2/test/X51007339653.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007339653.png
#   inflating: /content/Dataset/findit/findit2/test/X51005711453.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005711453.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005605295.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005605295.png
#   inflating: /content/Dataset/findit/findit2/test/X51005719864.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005719864.png
#   inflating: /content/Dataset/findit/findit2/test/X51006913019.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006913019.png
#   inflating: /content/Dataset/findit/findit2/test/X00016469676.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X00016469676.txt
#   inflating: /content/Dataset/findit/findit2/test/X51007103688.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007103688.txt
#   inflating: /content/Dataset/findit/findit2/test/X51008114217.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008114217.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006913031.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006913031.png
#   inflating: /content/Dataset/findit/findit2/test/X51008123450.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008123450.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006620182.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006620182.png
#   inflating: /content/Dataset/findit/findit2/test/X51006556838.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556838.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006414512.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006414512.png
#   inflating: /content/Dataset/findit/findit2/test/X51005433514.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005433514.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006556810.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556810.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006335552.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006335552.png
#   inflating: /content/Dataset/findit/findit2/test/X51007579714.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007579714.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005719905.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005719905.png
#   inflating: /content/Dataset/findit/findit2/test/X51007103702.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007103702.txt
#   inflating: /content/Dataset/findit/findit2/test/X51008099046.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008099046.txt
#   inflating: /content/Dataset/findit/findit2/test/X51008123451.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008123451.txt
#   inflating: /content/Dataset/findit/findit2/test/X51008114216.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008114216.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005705727.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005705727.png
#   inflating: /content/Dataset/findit/findit2/test/X51005447848.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005447848.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006414671.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006414671.png
#   inflating: /content/Dataset/findit/findit2/test/X51005757349.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005757349.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005230657.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005230657.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005676534.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005676534.png
#   inflating: /content/Dataset/findit/findit2/test/X51005447860.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005447860.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006388065.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006388065.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006327960.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006327960.png
#   inflating: /content/Dataset/findit/findit2/test/X51006556865.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556865.png
#   inflating: /content/Dataset/findit/findit2/test/X51007846326.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007846326.png
#   inflating: /content/Dataset/findit/findit2/test/X51008123447.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008123447.txt
#   inflating: /content/Dataset/findit/findit2/test/X51007846393.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007846393.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006401977.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006401977.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006328919.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006328919.png
#   inflating: /content/Dataset/findit/findit2/test/X51005587267.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005587267.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005749895.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005749895.png
#   inflating: /content/Dataset/findit/findit2/test/X51006414712.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006414712.png
#   inflating: /content/Dataset/findit/findit2/test/X51005719912.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005719912.png
#   inflating: /content/Dataset/findit/findit2/test/X51005676541.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005676541.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006414638.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006414638.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006556806.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556806.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006556812.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556812.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006555570.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006555570.png
#   inflating: /content/Dataset/findit/findit2/test/X51005442366.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005442366.png
#   inflating: /content/Dataset/findit/findit2/test/X51006414599.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006414599.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006619561.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006619561.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005676537.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005676537.png
#   inflating: /content/Dataset/findit/findit2/test/X51005757248.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005757248.png
#   inflating: /content/Dataset/findit/findit2/test/X51006329183.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006329183.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005685355.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005685355.png
#   inflating: /content/Dataset/findit/findit2/test/X51005676544.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005676544.png
#   inflating: /content/Dataset/findit/findit2/test/X51008114266.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008114266.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006556726.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556726.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006620191.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006620191.txt
#   inflating: /content/Dataset/findit/findit2/test/X51008042791.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008042791.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005745213.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005745213.png
#   inflating: /content/Dataset/findit/findit2/test/X51006556591.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556591.png
#   inflating: /content/Dataset/findit/findit2/test/X51005605286.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005605286.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006555818.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006555818.txt
#   inflating: /content/Dataset/findit/findit2/test/X51007339132.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007339132.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006557117.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006557117.png
#   inflating: /content/Dataset/findit/findit2/test/X51007339127.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007339127.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005568884.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005568884.png
#   inflating: /content/Dataset/findit/findit2/test/X51006913023.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006913023.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006350737.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006350737.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006401723.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006401723.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006557507.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006557507.png
#   inflating: /content/Dataset/findit/findit2/test/X51005806685.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005806685.png
#   inflating: /content/Dataset/findit/findit2/test/X51006620190.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006620190.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005676545.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005676545.png
#   inflating: /content/Dataset/findit/findit2/test/X51005577191.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005577191.png
#   inflating: /content/Dataset/findit/findit2/test/X51006619507.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006619507.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005447839.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005447839.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005675099.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005675099.png
#   inflating: /content/Dataset/findit/findit2/test/X51006828200.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006828200.png
#   inflating: /content/Dataset/findit/findit2/test/X51006713996.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006713996.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006557188.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006557188.txt
#   inflating: /content/Dataset/findit/findit2/test/X51007846357.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007846357.png
#   inflating: /content/Dataset/findit/findit2/test/X51006389963.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006389963.png
#   inflating: /content/Dataset/findit/findit2/test/X51006556828.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556828.png
#   inflating: /content/Dataset/findit/findit2/test/X51007846282.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007846282.txt
#   inflating: /content/Dataset/findit/findit2/test/X51007103639.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007103639.txt
#   inflating: /content/Dataset/findit/findit2/test/X51008099043.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008099043.png
#   inflating: /content/Dataset/findit/findit2/test/X51006387737.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006387737.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006008082.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006008082.txt
#   inflating: /content/Dataset/findit/findit2/test/X51008145504.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008145504.png
#   inflating: /content/Dataset/findit/findit2/test/X51005268275.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005268275.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005621482.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005621482.txt
#   inflating: /content/Dataset/findit/findit2/test/X51007339125.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007339125.txt
#   inflating: /content/Dataset/findit/findit2/test/X51007339642.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007339642.txt
#   inflating: /content/Dataset/findit/findit2/test/X51008145505.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008145505.png
#   inflating: /content/Dataset/findit/findit2/test/X51007339118.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007339118.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005442361.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005442361.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006556650.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556650.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006619764.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006619764.png
#   inflating: /content/Dataset/findit/findit2/test/X51006619869.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006619869.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005361898.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005361898.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005663277.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005663277.txt
#   inflating: /content/Dataset/findit/findit2/test/X51008099081.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008099081.png
#   inflating: /content/Dataset/findit/findit2/test/X51005745298.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005745298.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006556829.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556829.png
#   inflating: /content/Dataset/findit/findit2/test/X51005577192.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005577192.png
#   inflating: /content/Dataset/findit/findit2/test/X51005676546.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005676546.png
#   inflating: /content/Dataset/findit/findit2/test/X51005712017.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005712017.png
#   inflating: /content/Dataset/findit/findit2/test/X51006414715.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006414715.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005719905.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005719905.txt
#   inflating: /content/Dataset/findit/findit2/test/X51007103702.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007103702.png
#   inflating: /content/Dataset/findit/findit2/test/X51008099046.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008099046.png
#   inflating: /content/Dataset/findit/findit2/test/X51008123451.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008123451.png
#   inflating: /content/Dataset/findit/findit2/test/X51005705727.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005705727.txt
#   inflating: /content/Dataset/findit/findit2/test/X51008114216.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008114216.png
#   inflating: /content/Dataset/findit/findit2/test/X51005757349.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005757349.png
#   inflating: /content/Dataset/findit/findit2/test/X51005230657.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005230657.png
#   inflating: /content/Dataset/findit/findit2/test/X51006414671.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006414671.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005447848.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005447848.png
#   inflating: /content/Dataset/findit/findit2/test/X51005447860.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005447860.png
#   inflating: /content/Dataset/findit/findit2/test/X51005676534.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005676534.txt
#   inflating: /content/Dataset/findit/findit2/test/X51007339653.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007339653.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005711453.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005711453.png
#   inflating: /content/Dataset/findit/findit2/test/X51005719864.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005719864.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005605295.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005605295.txt
#   inflating: /content/Dataset/findit/findit2/test/X00016469676.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X00016469676.png
#   inflating: /content/Dataset/findit/findit2/test/X51006913019.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006913019.txt
#   inflating: /content/Dataset/findit/findit2/test/X51008114217.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008114217.png
#   inflating: /content/Dataset/findit/findit2/test/X51006913031.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006913031.txt
#   inflating: /content/Dataset/findit/findit2/test/X51007103688.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007103688.png
#   inflating: /content/Dataset/findit/findit2/test/X51008123450.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008123450.png
#   inflating: /content/Dataset/findit/findit2/test/X51006620182.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006620182.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006556838.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556838.png
#   inflating: /content/Dataset/findit/findit2/test/X51006556810.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556810.png
#   inflating: /content/Dataset/findit/findit2/test/X51005433514.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005433514.png
#   inflating: /content/Dataset/findit/findit2/test/X51006414512.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006414512.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006335552.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006335552.txt
#   inflating: /content/Dataset/findit/findit2/test/X51007579714.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007579714.png
#   inflating: /content/Dataset/findit/findit2/test/X51005719912.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005719912.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006414712.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006414712.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006414638.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006414638.png
#   inflating: /content/Dataset/findit/findit2/test/X51005676541.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005676541.png
#   inflating: /content/Dataset/findit/findit2/test/X51006556812.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556812.png
#   inflating: /content/Dataset/findit/findit2/test/X51006556806.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556806.png
#   inflating: /content/Dataset/findit/findit2/test/X51006555570.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006555570.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006414599.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006414599.png
#   inflating: /content/Dataset/findit/findit2/test/X51005442366.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005442366.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006619561.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006619561.png
#   inflating: /content/Dataset/findit/findit2/test/X51005676537.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005676537.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005757248.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005757248.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006388065.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006388065.png
#   inflating: /content/Dataset/findit/findit2/test/X51006327960.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006327960.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006556865.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556865.txt
#   inflating: /content/Dataset/findit/findit2/test/X51007846326.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007846326.txt
#   inflating: /content/Dataset/findit/findit2/test/X51008123447.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008123447.png
#   inflating: /content/Dataset/findit/findit2/test/X51007846393.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007846393.png
#   inflating: /content/Dataset/findit/findit2/test/X51006401977.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006401977.png
#   inflating: /content/Dataset/findit/findit2/test/X51006328919.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006328919.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005587267.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005587267.png
#   inflating: /content/Dataset/findit/findit2/test/X51005749895.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005749895.txt
#   inflating: /content/Dataset/findit/findit2/test/X51007339165.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007339165.png
#   inflating: /content/Dataset/findit/findit2/test/X51007339098.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007339098.txt
#   inflating: /content/Dataset/findit/findit2/test/X51007231361.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007231361.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005764161.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005764161.png
#   inflating: /content/Dataset/findit/findit2/test/X51005757324.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005757324.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006913061.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006913061.png
#   inflating: /content/Dataset/findit/findit2/test/X51006329388.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006329388.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005677337.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005677337.png
#   inflating: /content/Dataset/findit/findit2/test/X51006387932.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006387932.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006556840.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556840.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005724627.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005724627.png
#   inflating: /content/Dataset/findit/findit2/test/X51006619784.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006619784.png
#   inflating: /content/Dataset/findit/findit2/test/X51005447853.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005447853.png
#   inflating: /content/Dataset/findit/findit2/test/X51007339107.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007339107.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005337877.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005337877.png
#   inflating: /content/Dataset/findit/findit2/test/X51006388069.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006388069.png
#   inflating: /content/Dataset/findit/findit2/test/X51006414680.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006414680.txt
#   inflating: /content/Dataset/findit/findit2/test/X51007339648.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007339648.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006349086.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006349086.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005568866.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005568866.png
#   inflating: /content/Dataset/findit/findit2/test/X51006008089.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006008089.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006857126.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006857126.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006556841.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556841.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005705729.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005705729.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006335818.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006335818.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006619863.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006619863.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006556604.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556604.png
#   inflating: /content/Dataset/findit/findit2/test/X51006556610.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556610.png
#   inflating: /content/Dataset/findit/findit2/test/X51005433533.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005433533.png
#   inflating: /content/Dataset/findit/findit2/test/X51006466062.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006466062.png
#   inflating: /content/Dataset/findit/findit2/test/X51006913074.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006913074.png
#   inflating: /content/Dataset/findit/findit2/test/X51005711402.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005711402.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006334741.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006334741.png
#   inflating: /content/Dataset/findit/findit2/test/X51006619342.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006619342.png
#   inflating: /content/Dataset/findit/findit2/test/X51005757233.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005757233.png
#   inflating: /content/Dataset/findit/findit2/test/X51006557195.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006557195.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005745190.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005745190.png
#   inflating: /content/Dataset/findit/findit2/test/X51007846410.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007846410.png
#   inflating: /content/Dataset/findit/findit2/test/X00016469619.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X00016469619.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006502531.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006502531.png
#   inflating: /content/Dataset/findit/findit2/test/X51005442382.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005442382.txt
#   inflating: /content/Dataset/findit/findit2/test/X510056849111.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X510056849111.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005453729.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005453729.txt
#   inflating: /content/Dataset/findit/findit2/test/X51007843145.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007843145.png
#   inflating: /content/Dataset/findit/findit2/test/X51005447851.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005447851.png
#   inflating: /content/Dataset/findit/findit2/test/X51005442397.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005442397.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005433552.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005433552.txt
#   inflating: /content/Dataset/findit/findit2/test/X51008164991.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008164991.txt
#   inflating: /content/Dataset/findit/findit2/test/X51008099088.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008099088.png
#   inflating: /content/Dataset/findit/findit2/test/X51006556808.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556808.png
#   inflating: /content/Dataset/findit/findit2/test/X51005568911.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005568911.png
#   inflating: /content/Dataset/findit/findit2/test/X51006414720.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006414720.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005288570.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005288570.txt
#   inflating: /content/Dataset/findit/findit2/test/X51007339639.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007339639.png
#   inflating: /content/Dataset/findit/findit2/test/X51006619345.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006619345.png
#   inflating: /content/Dataset/findit/findit2/test/X51005675095.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005675095.png
#   inflating: /content/Dataset/findit/findit2/test/X51005757220.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005757220.png
#   inflating: /content/Dataset/findit/findit2/test/X51006557184.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006557184.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006008105.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006008105.txt
#   inflating: /content/Dataset/findit/findit2/test/X00016469620.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X00016469620.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006414532.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006414532.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006556830.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556830.png
#   inflating: /content/Dataset/findit/findit2/test/X51007846398.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007846398.png
#   inflating: /content/Dataset/findit/findit2/test/X51008099073.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008099073.png
#   inflating: /content/Dataset/findit/findit2/test/X51006556603.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556603.png
#   inflating: /content/Dataset/findit/findit2/test/X51005677331.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005677331.png
#   inflating: /content/Dataset/findit/findit2/test/X51005433556.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005433556.txt
#   inflating: /content/Dataset/findit/findit2/test/X51008142059.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008142059.png
#   inflating: /content/Dataset/findit/findit2/test/X51005757243.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005757243.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005268408.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005268408.png
#   inflating: /content/Dataset/findit/findit2/test/X51009008091.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51009008091.png
#   inflating: /content/Dataset/findit/findit2/test/X51005433543.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005433543.txt
#   inflating: /content/Dataset/findit/findit2/test/X51008142058.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008142058.png
#   inflating: /content/Dataset/findit/findit2/test/X51006556648.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556648.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006557508.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006557508.png
#   inflating: /content/Dataset/findit/findit2/test/X51007846270.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007846270.txt
#   inflating: /content/Dataset/findit/findit2/test/X51007846366.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007846366.png
#   inflating: /content/Dataset/findit/findit2/test/X51006414533.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006414533.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005568914.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005568914.png
#   inflating: /content/Dataset/findit/findit2/test/X51005746206.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005746206.txt
#   inflating: /content/Dataset/findit/findit2/test/X51007339638.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007339638.png
#   inflating: /content/Dataset/findit/findit2/test/X51005724554.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005724554.png
#   inflating: /content/Dataset/findit/findit2/test/X51007231364.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007231364.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006555784.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006555784.txt
#   inflating: /content/Dataset/findit/findit2/test/X51007231370.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007231370.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006556827.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006556827.png
#   inflating: /content/Dataset/findit/findit2/test/X51008142038.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51008142038.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006008206.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006008206.png
#   inflating: /content/Dataset/findit/findit2/test/X51006414519.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006414519.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006620189.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006620189.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006647933.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006647933.txt
#   inflating: /content/Dataset/findit/findit2/test/X00016469669.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X00016469669.png
#   inflating: /content/Dataset/findit/findit2/test/X51007103597.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007103597.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005447842.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005447842.png
#   inflating: /content/Dataset/findit/findit2/test/X51007339116.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51007339116.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006438346.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006438346.txt
#   inflating: /content/Dataset/findit/findit2/test/X51006388044.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006388044.png
#   inflating: /content/Dataset/findit/findit2/test/X51006008073.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006008073.txt
#   inflating: /content/Dataset/findit/findit2/test/X51005337872.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51005337872.png
#   inflating: /content/Dataset/findit/findit2/test/X51006392122.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/test/._X51006392122.txt
# ...
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51008164997.txt
#   inflating: /content/Dataset/findit/findit2/val/X51008042777.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51008042777.txt
#   inflating: /content/Dataset/findit/findit2/val/X51005663278.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005663278.txt
#   inflating: /content/Dataset/findit/findit2/val/X51005441407.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005441407.png
#   inflating: /content/Dataset/findit/findit2/val/X51005200931.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005200931.txt
#   inflating: /content/Dataset/findit/findit2/val/X51005757292.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005757292.png
#   inflating: /content/Dataset/findit/findit2/val/X51005568899.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005568899.txt
#   inflating: /content/Dataset/findit/findit2/val/X51005749912.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005749912.png
#   inflating: /content/Dataset/findit/findit2/val/X51005447852.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005447852.txt
#   inflating: /content/Dataset/findit/findit2/val/X51008099100.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51008099100.txt
#   inflating: /content/Dataset/findit/findit2/val/X51008142062.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51008142062.txt
#   inflating: /content/Dataset/findit/findit2/val/X51006857132.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006857132.png
#   inflating: /content/Dataset/findit/findit2/val/X51006619785.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006619785.txt
#   inflating: /content/Dataset/findit/findit2/val/X51005724626.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005724626.txt
#   inflating: /content/Dataset/findit/findit2/val/X51007103687.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51007103687.txt
#   inflating: /content/Dataset/findit/findit2/val/X51005444040.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005444040.png
#   inflating: /content/Dataset/findit/findit2/val/X51008099048.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51008099048.txt
#   inflating: /content/Dataset/findit/findit2/val/X51006502533.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006502533.txt
#   inflating: /content/Dataset/findit/findit2/val/X51006414392.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006414392.txt
#   inflating: /content/Dataset/findit/findit2/val/X51006555780.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006555780.png
#   inflating: /content/Dataset/findit/findit2/val/X51005712021.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005712021.txt
#   inflating: /content/Dataset/findit/findit2/val/X51006557169.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006557169.png
#   inflating: /content/Dataset/findit/findit2/val/X51007579726.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51007579726.txt
#   inflating: /content/Dataset/findit/findit2/val/X51005745187.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005745187.txt
#   inflating: /content/Dataset/findit/findit2/val/X51006387950.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006387950.txt
#   inflating: /content/Dataset/findit/findit2/val/X51008114284.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51008114284.png
#   inflating: /content/Dataset/findit/findit2/val/X51008099049.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51008099049.txt
#   inflating: /content/Dataset/findit/findit2/val/X51005444037.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005444037.txt
#   inflating: /content/Dataset/findit/findit2/val/X51008123476.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51008123476.txt
#   inflating: /content/Dataset/findit/findit2/val/X51005444041.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005444041.png
#   inflating: /content/Dataset/findit/findit2/val/X51006554833.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006554833.txt
#   inflating: /content/Dataset/findit/findit2/val/X51005741929.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005741929.txt
#   inflating: /content/Dataset/findit/findit2/val/X51006414483.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006414483.png
#   inflating: /content/Dataset/findit/findit2/val/X51005757346.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005757346.txt
#   inflating: /content/Dataset/findit/findit2/val/X51006619545.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006619545.txt
#   inflating: /content/Dataset/findit/findit2/val/X51006912960.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006912960.txt
#   inflating: /content/Dataset/findit/findit2/val/X51005719895.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005719895.png
#   inflating: /content/Dataset/findit/findit2/val/X51006912976.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006912976.txt
#   inflating: /content/Dataset/findit/findit2/val/X51007339139.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51007339139.png
#   inflating: /content/Dataset/findit/findit2/val/X51005676539.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005676539.png
#   inflating: /content/Dataset/findit/findit2/val/X51006327953.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006327953.png
#   inflating: /content/Dataset/findit/findit2/val/X51008142061.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51008142061.txt
#   inflating: /content/Dataset/findit/findit2/val/X51005677335.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005677335.txt
#   inflating: /content/Dataset/findit/findit2/val/X51005441401.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005441401.txt
#   inflating: /content/Dataset/findit/findit2/val/X51006557194.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006557194.png
#   inflating: /content/Dataset/findit/findit2/val/X51006414636.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006414636.txt
#   inflating: /content/Dataset/findit/findit2/val/X51007231275.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51007231275.txt
#   inflating: /content/Dataset/findit/findit2/val/X51007579725.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51007579725.txt
#   inflating: /content/Dataset/findit/findit2/val/X51005230605.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005230605.png
#   inflating: /content/Dataset/findit/findit2/val/X51006555125.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006555125.txt
#   inflating: /content/Dataset/findit/findit2/val/X51008099089.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51008099089.txt
#   inflating: /content/Dataset/findit/findit2/val/X51006556821.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006556821.txt
#   inflating: /content/Dataset/findit/findit2/val/X51005677334.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005677334.txt
#   inflating: /content/Dataset/findit/findit2/val/X51006556658.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006556658.png
#   inflating: /content/Dataset/findit/findit2/val/X51005724624.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005724624.txt
#   inflating: /content/Dataset/findit/findit2/val/X51008142060.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51008142060.txt
#   inflating: /content/Dataset/findit/findit2/val/X51005447844.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005447844.txt
#   inflating: /content/Dataset/findit/findit2/val/X51005676538.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005676538.png
#   inflating: /content/Dataset/findit/findit2/val/X51009008095.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51009008095.txt
#   inflating: /content/Dataset/findit/findit2/val/X51005719896.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005719896.png
#   inflating: /content/Dataset/findit/findit2/val/X51007339110.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51007339110.png
#   inflating: /content/Dataset/findit/findit2/val/X51007339114.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51007339114.png
#   inflating: /content/Dataset/findit/findit2/val/X51008164510.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51008164510.txt
#   inflating: /content/Dataset/findit/findit2/val/X51006008166.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006008166.txt
#   inflating: /content/Dataset/findit/findit2/val/X51007225417.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51007225417.txt
#   inflating: /content/Dataset/findit/findit2/val/X51006714066.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006714066.txt
#   inflating: /content/Dataset/findit/findit2/val/X51007846310.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51007846310.png
#   inflating: /content/Dataset/findit/findit2/val/X51006619783.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006619783.txt
#   inflating: /content/Dataset/findit/findit2/val/X51005442392.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005442392.png
#   inflating: /content/Dataset/findit/findit2/val/X51005442386.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005442386.png
#   inflating: /content/Dataset/findit/findit2/val/X51005444046.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005444046.png
#   inflating: /content/Dataset/findit/findit2/val/X51006311764.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006311764.png
#   inflating: /content/Dataset/findit/findit2/val/X51008114283.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51008114283.png
#   inflating: /content/Dataset/findit/findit2/val/X51007135247.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51007135247.txt
#   inflating: /content/Dataset/findit/findit2/val/X51007846372.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51007846372.txt
#   inflating: /content/Dataset/findit/findit2/val/X51006466070.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006466070.txt
#   inflating: /content/Dataset/findit/findit2/val/X51006328913.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006328913.png
#   inflating: /content/Dataset/findit/findit2/val/X51005711404.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005711404.png
#   inflating: /content/Dataset/findit/findit2/val/X51005757323.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005757323.png
#   inflating: /content/Dataset/findit/findit2/val/X51005715006.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005715006.txt
#   inflating: /content/Dataset/findit/findit2/val/X51006414719.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006414719.png
#   inflating: /content/Dataset/findit/findit2/val/X51006393377.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006393377.png
#   inflating: /content/Dataset/findit/findit2/val/X51005722668.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005722668.txt
#   inflating: /content/Dataset/findit/findit2/val/X51006913073.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006913073.txt
#   inflating: /content/Dataset/findit/findit2/val/X51006620161.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006620161.png
#   inflating: /content/Dataset/findit/findit2/val/X51005442344.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005442344.png
#   inflating: /content/Dataset/findit/findit2/val/X51008064061.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51008064061.txt
#   inflating: /content/Dataset/findit/findit2/val/X51008142065.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51008142065.txt
#   inflating: /content/Dataset/findit/findit2/val/X51005447841.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005447841.txt
#   inflating: /content/Dataset/findit/findit2/val/X51006557119.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006557119.txt
#   inflating: /content/Dataset/findit/findit2/val/X51007225399.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51007225399.txt
#   inflating: /content/Dataset/findit/findit2/val/X51007339117.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51007339117.png
#   inflating: /content/Dataset/findit/findit2/val/X51007103641.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51007103641.txt
#   inflating: /content/Dataset/findit/findit2/val/X51005806702.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005806702.txt
#   inflating: /content/Dataset/findit/findit2/val/X51005677327.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005677327.txt
#   inflating: /content/Dataset/findit/findit2/val/X51008164997.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51008164997.png
#   inflating: /content/Dataset/findit/findit2/val/X51005663278.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005663278.png
#   inflating: /content/Dataset/findit/findit2/val/X51008042777.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51008042777.png
#   inflating: /content/Dataset/findit/findit2/val/X51005200931.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005200931.png
#   inflating: /content/Dataset/findit/findit2/val/X51005441407.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005441407.txt
#   inflating: /content/Dataset/findit/findit2/val/X51006619346.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006619346.txt
#   inflating: /content/Dataset/findit/findit2/val/X51005676548.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005676548.txt
#   inflating: /content/Dataset/findit/findit2/val/X51007846370.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51007846370.txt
#   inflating: /content/Dataset/findit/findit2/val/X51006620176.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006620176.png
#   inflating: /content/Dataset/findit/findit2/val/X51008114281.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51008114281.png
#   inflating: /content/Dataset/findit/findit2/val/X51005677332.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005677332.txt
#   inflating: /content/Dataset/findit/findit2/val/X51006556851.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51006556851.png
#   inflating: /content/Dataset/findit/findit2/val/X51005757282.png
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005757282.png
#   inflating: /content/Dataset/findit/findit2/val/X51005763964.txt
#   inflating: /content/Dataset/findit/__MACOSX/findit2/val/._X51005763964.txt

# %% [markdown]
# # Create Dataframes

# %%
import json

def parse_annotation_to_dict(annotation):
    parts = annotation.strip().split(',')

    image_filename = parts[0].strip()
    digital_annotation = int(parts[1].strip())
    handwritten_annotation = int(parts[2].strip())
    forged = int(parts[3].strip())

    forgery_annotations_str = ','.join(parts[4:]).strip()  # Convert string representation of dictionary to dictionary

    if forgery_annotations_str != '0':
        try:
            forgery_annotations_str = forgery_annotations_str.encode('unicode_escape').decode('utf-8')
            forgery_annotations_json = json.loads(forgery_annotations_str)  # Convert string to dictionary
            filename = forgery_annotations_json.get('filename', '')
            size = forgery_annotations_json.get('size', '')

            regions = forgery_annotations_json.get('regions', [])
            Name = []
            X = []
            Y = []
            W = []
            H = []
            Modified_Area = []
            Entity = []
            Original_Area = []

            for region in regions:
                shape_attributes = region.get('shape_attributes', {})
                Name.append(shape_attributes.get('name', ''))
                X.append(shape_attributes.get('x', ''))
                Y.append(shape_attributes.get('y', ''))
                W.append(shape_attributes.get('width', ''))
                H.append(shape_attributes.get('height', ''))

                region_attributes = region.get('region_attributes', {})
                Modified_Area.append(region_attributes.get('Modified area', ''))
                Entity.append(region_attributes.get('Entity type', ''))
                Original_Area.append(region_attributes.get('Original area', ''))
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON: {e}")
            print(f"Problematic JSON string: {forgery_annotations_str}")
            # Assign default values if JSON decoding fails
            forgery_annotations_json = {}
            filename, size = '', ''
            Name, X, Y, W, H = [], [], [], [], []
            Modified_Area, Entity, Original_Area = [], [], []
    else:
        filename, size = '', ''
        Name, X, Y, W, H = [], [], [], [], []
        Modified_Area, Entity, Original_Area = [], [], []

    return {
        "image": image_filename,
        "digital_annotation": digital_annotation,
        "handwritten_annotation": handwritten_annotation,
        "forged": forged,
        "forgery_annotations": forgery_annotations_str,
        "filename": filename,
        "size": size,
        "name": Name,
        "x": X,
        "y": Y,
        "w": W,
        "h": H,
        "modified_area": Modified_Area,
        "entity": Entity,
        "original_area": Original_Area
    }

# %%
def txt_to_dataframe(txt_file):
    with open(txt_file, 'r') as f:
        lines = f.readlines()[1:]  # Skip header
        annotations = [parse_annotation_to_dict(line) for line in lines]

    return pd.DataFrame(annotations)

# %%
txt_file = "/content/Dataset/findit/train_json.txt"
df = txt_to_dataframe(txt_file)

df.head()
# Out:
#               image  digital_annotation  handwritten_annotation  forged  \
# 0  X00016469622.png                   1                       1       1
# 1  X00016469623.png                   1                       1       0
# 2  X00016469670.png                   1                       1       0
# 3  X00016469671.png                   1                       1       0
# 4  X00016469672.png                   1                       1       0
#
#                                  forgery_annotations          filename  \
# 0  {"filename": "X00016469622.png", "size": 23072...  X00016469622.png
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#      size                                              name  \
# 0  230726  [rect, rect, rect, rect, rect, rect, rect, rect]
# 1                                                        []
# 2                                                        []
# 3                                                        []
# 4                                                        []
#
#                                           x  \
# 0  [248, 405, 345, 347, 344, 343, 266, 268]
# 1                                        []
# 2                                        []
# 3                                        []
# 4                                        []
#
#                                           y                              w  \
# 0  [459, 342, 461, 510, 547, 657, 812, 845]  [13, 13, 9, 8, 10, 12, 12, 9]
# 1                                        []                             []
# 2                                        []                             []
# 3                                        []                             []
# 4                                        []                             []
#
#                                   h  \
# 0  [18, 17, 16, 16, 16, 18, 20, 17]
# 1                                []
# 2                                []
# 3                                []
# 4                                []
#
#                                        modified_area  \
# 0  [{'CPI': 'True'}, {'None': 'True'}, {'CPI': 'T...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                               entity  \
# 0  [Product, Metadata, Product, Product, Total/pa...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                        original_area
# 0  [no, yes, no, no, no, no, no, no]
# 1                                 []
# 2                                 []
# 3                                 []
# 4                                 []

# %%
df.to_csv('train.csv', index = False)

# %%
# import json

# # Get the forgery_annotations for the 5th row (index 4)
# forgery_annotations_str = df.iloc[4]['forgery_annotations']

# # Replace single quotes with double quotes
# forgery_annotations_str = forgery_annotations_str.replace("'", "\"").strip()

# print(forgery_annotations_str)

# # Attempt to load the JSON from the string
# try:
#     forgery_annotations_json = json.loads(forgery_annotations_str)
#     filename = forgery_annotations_json['regions']
#     print(filename)
#     print(filename[0]['shape_attributes']['name'])
#     print(len(filename))
# except json.JSONDecodeError as e:
#     print("Error decoding JSON:", e)
# Out:
# {"filename": "X51005230616.png", "size": 835401, "regions": [{"shape_attributes": {"name": "rect", "x": 27, "y": 875, "width": 29, "height": 43}, "region_attributes": {"Modified area": {"IMI": "True"}, "Entity type": "Product", "Original area": "no"}}, {"shape_attributes": {"name": "rect", "x": 458, "y": 883, "width": 35, "height": 37}, "region_attributes": {"Modified area": {"IMI": "True"}, "Entity type": "Product", "Original area": "no"}}], "file_attributes": {"Software used": "paint"}}
# [{'shape_attributes': {'name': 'rect', 'x': 27, 'y': 875, 'width': 29, 'height': 43}, 'region_attributes': {'Modified area': {'IMI': 'True'}, 'Entity type': 'Product', 'Original area': 'no'}}, {'shape_attributes': {'name': 'rect', 'x': 458, 'y': 883, 'width': 35, 'height': 37}, 'region_attributes': {'Modified area': {'IMI': 'True'}, 'Entity type': 'Product', 'Original area': 'no'}}]
# rect
# 2

# %%
# import re
# import json

# # Original JSON string
# json_str = "{\"filename\": \"X51005230616.png\", \"size\": 835401, \"regions\": [{\"shape_attributes\": {\"name\": \"rect\", \"x\": 27, \"y\": 875, \"width\": 29, \"height\": 43}, \"region_attributes\": {\"Modified area\": {\"IMI\": True}, \"Entity type\": \"Product\", \"Original area\": \"no\"}}, {\"shape_attributes\": {\"name\": \"rect\", \"x\": 458, \"y\": 883, \"width\": 35, \"height\": 37}, \"region_attributes\": {\"Modified area\": {\"IMI\": True}, \"Entity type\": \"Product\", \"Original area\": \"no\"}}], \"file_attributes\": {\"Software used\": \"paint\"}}"

# # Use regular expression to remove non-JSON characters
# clean_json_str = re.sub(r'[^{}[\],\s\d.:a-zA-Z_"]', '', json_str)

# print("Clean JSON string:", clean_json_str)

# try:
#     forgery_annotations_json = json.loads(clean_json_str)
#     print("JSON decoding successful.")
#     print(forgery_annotations_json)
# except json.JSONDecodeError as e:
#     print("Error decoding JSON:", e)
# Out:
# Clean JSON string: {"filename": "X51005230616.png", "size": 835401, "regions": [{"shape_attributes": {"name": "rect", "x": 27, "y": 875, "width": 29, "height": 43}, "region_attributes": {"Modified area": {"IMI": True}, "Entity type": "Product", "Original area": "no"}}, {"shape_attributes": {"name": "rect", "x": 458, "y": 883, "width": 35, "height": 37}, "region_attributes": {"Modified area": {"IMI": True}, "Entity type": "Product", "Original area": "no"}}], "file_attributes": {"Software used": "paint"}}
# Error decoding JSON: Expecting value: line 1 column 194 (char 193)

# %% [markdown]
# # Plot masks - bounding boxes

# %%
df = pd.read_csv('/content/val.csv')
df.fillna(0, inplace = True)

columns_to_drop = ['forgery_annotations']
df.drop(columns = columns_to_drop, inplace = True)

df.head(5)
# Out:
#               image  digital_annotation  handwritten_annotation  forged  \
# 0  X00016469612.png                   1                       1       1
# 1  X51005200931.png                   0                       1       0
# 2  X51005230605.png                   0                       0       0
# 3  X51005433538.png                   0                       1       0
# 4  X51005441401.png                   0                       1       1
#
#            filename      size  \
# 0  X00016469612.png  291659.0
# 1                 0       0.0
# 2                 0       0.0
# 3                 0       0.0
# 4  X51005441401.png  358358.0
#
#                                                 name  \
# 0                   ['rect', 'rect', 'rect', 'rect']
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  ['rect', 'rect', 'rect', 'rect', 'rect', 'rect...
#
#                                      x                                    y  \
# 0                 [174, 164, 318, 179]                 [374, 373, 372, 396]
# 1                                   []                                   []
# 2                                   []                                   []
# 3                                   []                                   []
# 4  [418, 416, 417, 414, 416, 418, 430]  [595, 623, 674, 717, 743, 815, 764]
#
#                               w                             h  \
# 0                [9, 9, 13, 10]              [14, 15, 16, 18]
# 1                            []                            []
# 2                            []                            []
# 3                            []                            []
# 4  [12, 15, 12, 14, 14, 13, 14]  [24, 27, 37, 20, 17, 42, 24]
#
#                                        modified_area  \
# 0  [{'CPI': 'True'}, {'None': 'True'}, {'CPI': 'T...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'CUT': 'True'}, {'CUT': 'True'}, {'CUT': 'Tr...
#
#                                               entity  \
# 0      ['Metadata', 'Metadata', 'Metadata', 'Other']
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  ['Product', 'Product', 'Total/payment', 'Total...
#
#                                  original_area
# 0                   ['no', 'yes', 'no', 'yes']
# 1                                           []
# 2                                           []
# 3                                           []
# 4  ['no', 'no', 'no', 'no', 'no', 'no', 'yes']

# %%
import matplotlib.patches as patches
import cv2
import ast

def draw_boxes(image_path, df_row, save_path):
    try:
        # Read the image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Unable to read image: {image_path}")
            return

        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # Plot the image without axes
        fig, ax = plt.subplots(1)
        ax.imshow(image_rgb)
        ax.axis('off')  # Turn off axes

        # Parse annotations and draw bounding boxes
        for x, y, w, h in zip(ast.literal_eval(df_row['x']), ast.literal_eval(df_row['y']), ast.literal_eval(df_row['w']), ast.literal_eval(df_row['h'])):
            # Draw rectangle
            rect = patches.Rectangle((int(x), int(y)), int(w), int(h), linewidth=1, edgecolor='r', facecolor='none')
            ax.add_patch(rect)

        # Save the processed image with bounding boxes
        mask_path = os.path.join(save_path, os.path.basename(image_path))
        plt.savefig(mask_path, bbox_inches='tight', pad_inches=0)
        plt.close()
    except Exception as e:
        print(f"Error processing image: {image_path}")
        print(f"Error message: {e}")


# Create folder to save masks if it does not exist
save_folder = '/content/Dataset/findit/findit2/test_masks'
if not os.path.exists(save_folder):
    os.makedirs(save_folder)

# df = pd.DataFrame(data)
forged_df = df[df['forged'] == 1]

# Iterate over DataFrame rows and draw bounding boxes
for index, row in forged_df.iterrows():
    image_name = row['filename']
    image_path = '/content/Dataset/findit/findit2/test/' + image_name
    draw_boxes(image_path, row, save_folder)

# %%
def create_binary_mask(image_shape, bbox_list):
    # Create a blank black image
    mask = np.zeros(image_shape, dtype=np.uint8)

    # Draw white rectangles for bounding boxes
    for x, y, w, h in bbox_list:
        cv2.rectangle(mask, (x, y), (x+w, y+h), (255, 255, 255), -1)  # -1 to fill the rectangle

    return mask

def draw_boxes(image_path, df_row, save_path):
    try:
        # Read the image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Unable to read image: {image_path}")
            return

        # Get image dimensions
        height, width, _ = image.shape

        # Parse annotations and get bounding boxes
        bbox_list = list(zip(ast.literal_eval(df_row['x']), ast.literal_eval(df_row['y']), ast.literal_eval(df_row['w']), ast.literal_eval(df_row['h'])))

        # Create binary mask
        mask = create_binary_mask((height, width, 3), bbox_list)

        # Save the processed image with bounding boxes
        mask_path = os.path.join(save_path, os.path.basename(image_path))
        cv2.imwrite(mask_path, mask)
    except Exception as e:
        print(f"Error processing image: {image_path}")
        print(f"Error message: {e}")

# Create folder to save masks if it does not exist
save_folder = '/content/Dataset/findit/findit2/val_bm'
if not os.path.exists(save_folder):
    os.makedirs(save_folder)

# Filter rows with forged = 1
forged_df = df[df['forged'] == 1]

# Iterate over DataFrame rows and draw bounding boxes
for index, row in forged_df.iterrows():
    image_name = row['filename']
    image_path = '/content/Dataset/findit/findit2/val/' + image_name
    draw_boxes(image_path, row, save_folder)
# Out:
# Unable to read image: /content/Dataset/findit/findit2/val/X51006619709.png

# %%
# !rm -r /content/Dataset/findit/findit2/train_masks

# %%
import zipfile
import os

# Define the folder you want to zip and the name of the zip file
folder_to_zip = '/content/Dataset'
zip_file_name = '/content/Dataset.zip'

# Create a zip file
with zipfile.ZipFile(zip_file_name, 'w') as zipf:
    # Iterate over all the files in the folder
    for root, _, files in os.walk(folder_to_zip):
        for file in files:
            # Get the full path of the file
            file_path = os.path.join(root, file)
            # Add the file to the zip
            zipf.write(file_path, os.path.relpath(file_path, folder_to_zip))

# Print message when done
print(f"Folder '{folder_to_zip}' zipped successfully as '{zip_file_name}'.")
# Out:
# Folder '/content/Dataset' zipped successfully as '/content/Dataset.zip'.

# %%
from google.colab import files

# Specify the path to the zip file you want to download
zip_file_path = '/content/Dataset.zip'

# Download the file
files.download(zip_file_path)
