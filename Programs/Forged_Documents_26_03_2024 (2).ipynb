# %%
# !pip install segmentation_models_pytorch
# !pip install wandb

# %% [markdown]
# # Iniatial

# %%
# !mkdir Master
# !mkdir Master/IMD2020

# !wget -P Master/IMD2020 https://staff.utia.cas.cz/novozada/db/IMD2020.zip
# Out:
# --2024-03-26 22:35:58--  https://staff.utia.cas.cz/novozada/db/IMD2020.zip
# Resolving staff.utia.cas.cz (staff.utia.cas.cz)... 147.231.16.197
# Connecting to staff.utia.cas.cz (staff.utia.cas.cz)|147.231.16.197|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 592836398 (565M) [application/zip]
# Saving to: ‘Master/IMD2020/IMD2020.zip’
#
# IMD2020.zip         100%[===================>] 565.37M  10.6MB/s    in 2m 31s
#
# 2024-03-26 22:38:30 (3.75 MB/s) - ‘Master/IMD2020/IMD2020.zip’ saved [592836398/592836398]

# %%
# !unzip /content/Master/IMD2020/IMD2020.zip -d Master/IMD2020
# Out:
# Archive:  /content/Master/IMD2020/IMD2020.zip
#    creating: Master/IMD2020/1a1ogs/
#   inflating: Master/IMD2020/1a1ogs/1a1ogs_orig.jpg
#   inflating: Master/IMD2020/1a1ogs/c8tf5mq_0.png
#   inflating: Master/IMD2020/1a1ogs/c8tf5mq_0_mask.png
#    creating: Master/IMD2020/1a3oag/
#   inflating: Master/IMD2020/1a3oag/1a3oag_orig.jpg
#   inflating: Master/IMD2020/1a3oag/c8tt7fg_0.jpg
#   inflating: Master/IMD2020/1a3oag/c8tt7fg_0_mask.png
#   inflating: Master/IMD2020/1a3oag/c8ttni9_0.jpg
#   inflating: Master/IMD2020/1a3oag/c8ttni9_0_mask.png
#   inflating: Master/IMD2020/1a3oag/c8ttxcu_0.jpg
#   inflating: Master/IMD2020/1a3oag/c8ttxcu_0_mask.png
#   inflating: Master/IMD2020/1a3oag/c8ttxi0_0.jpg
#   inflating: Master/IMD2020/1a3oag/c8ttxi0_0_mask.png
#   inflating: Master/IMD2020/1a3oag/c8tvsnn_0.jpg
#   inflating: Master/IMD2020/1a3oag/c8tvsnn_0_mask.png
#   inflating: Master/IMD2020/1a3oag/c8twn73_0.jpg
#   inflating: Master/IMD2020/1a3oag/c8twn73_0_mask.png
#   inflating: Master/IMD2020/1a3oag/c8twvej_0.jpg
#   inflating: Master/IMD2020/1a3oag/c8twvej_0_mask.png
#   inflating: Master/IMD2020/1a3oag/c8tx1h1_0.jpg
#   inflating: Master/IMD2020/1a3oag/c8tx1h1_0_mask.png
#   inflating: Master/IMD2020/1a3oag/c8txu5x_0.jpg
#   inflating: Master/IMD2020/1a3oag/c8txu5x_0_mask.png
#   inflating: Master/IMD2020/1a3oag/c8u0rrz_0.jpg
#   inflating: Master/IMD2020/1a3oag/c8u0rrz_0_mask.png
#   inflating: Master/IMD2020/1a3oag/c8u0wl4_0.jpg
#   inflating: Master/IMD2020/1a3oag/c8u0wl4_0_mask.png
#    creating: Master/IMD2020/1a4dqp/
#   inflating: Master/IMD2020/1a4dqp/1a4dqp_orig.jpg
#   inflating: Master/IMD2020/1a4dqp/c8u4gpd_0.jpg
#   inflating: Master/IMD2020/1a4dqp/c8u4gpd_0_mask.png
#    creating: Master/IMD2020/1a4zdz/
#   inflating: Master/IMD2020/1a4zdz/1a4zdz_orig.jpg
#   inflating: Master/IMD2020/1a4zdz/c8u86mv_0.jpg
#   inflating: Master/IMD2020/1a4zdz/c8u86mv_0_mask.png
#   inflating: Master/IMD2020/1a4zdz/c8uaap3_0.jpg
#   inflating: Master/IMD2020/1a4zdz/c8uaap3_0_mask.png
#   inflating: Master/IMD2020/1a4zdz/c8uaesm_0.jpg
#   inflating: Master/IMD2020/1a4zdz/c8uaesm_0_mask.png
#   inflating: Master/IMD2020/1a4zdz/c8ubux0_0.jpg
#   inflating: Master/IMD2020/1a4zdz/c8ubux0_0_mask.png
#   inflating: Master/IMD2020/1a4zdz/c8ucm3b_0.jpg
#   inflating: Master/IMD2020/1a4zdz/c8ucm3b_0_mask.png
#   inflating: Master/IMD2020/1a4zdz/c8uf70a_0.jpg
#   inflating: Master/IMD2020/1a4zdz/c8uf70a_0_mask.png
#    creating: Master/IMD2020/1a5h1p/
#   inflating: Master/IMD2020/1a5h1p/1a5h1p_orig.jpg
#   inflating: Master/IMD2020/1a5h1p/c8ua0at_0.jpg
#   inflating: Master/IMD2020/1a5h1p/c8ua0at_0_mask.png
#   inflating: Master/IMD2020/1a5h1p/c8uc2z3_0.jpg
#   inflating: Master/IMD2020/1a5h1p/c8uc2z3_0_mask.png
#   inflating: Master/IMD2020/1a5h1p/c8ue2m3_0.jpg
#   inflating: Master/IMD2020/1a5h1p/c8ue2m3_0_mask.png
#    creating: Master/IMD2020/1a5x44/
#   inflating: Master/IMD2020/1a5x44/1a5x44_orig.jpg
#   inflating: Master/IMD2020/1a5x44/c8uefj0_0.jpg
#   inflating: Master/IMD2020/1a5x44/c8uefj0_0_mask.png
#   inflating: Master/IMD2020/1a5x44/c8ufqah_0.png
#   inflating: Master/IMD2020/1a5x44/c8ufqah_0_mask.png
#   inflating: Master/IMD2020/1a5x44/c8ufr4g_0.jpg
#   inflating: Master/IMD2020/1a5x44/c8ufr4g_0_mask.png
#   inflating: Master/IMD2020/1a5x44/c8uiddx_0.png
#   inflating: Master/IMD2020/1a5x44/c8uiddx_0_mask.png
#   inflating: Master/IMD2020/1a5x44/c8uiv5e_0.jpg
#   inflating: Master/IMD2020/1a5x44/c8uiv5e_0_mask.png
#    creating: Master/IMD2020/1a6upj/
#   inflating: Master/IMD2020/1a6upj/1a6upj_orig.jpg
#   inflating: Master/IMD2020/1a6upj/c8umnyd_0.jpg
#   inflating: Master/IMD2020/1a6upj/c8umnyd_0_mask.png
#   inflating: Master/IMD2020/1a6upj/c8uopdm_0.jpg
#   inflating: Master/IMD2020/1a6upj/c8uopdm_0_mask.png
#    creating: Master/IMD2020/1a07yi/
#   inflating: Master/IMD2020/1a07yi/1a07yi_orig.jpg
#   inflating: Master/IMD2020/1a07yi/c8swtoq_0.jpg
#   inflating: Master/IMD2020/1a07yi/c8swtoq_0_mask.png
#    creating: Master/IMD2020/1a8jd2/
#   inflating: Master/IMD2020/1a8jd2/1a8jd2_orig.jpg
#   inflating: Master/IMD2020/1a8jd2/c8v2pbm_0.jpg
#   inflating: Master/IMD2020/1a8jd2/c8v2pbm_0_mask.png
#   inflating: Master/IMD2020/1a8jd2/c8v2xno_0.jpg
#   inflating: Master/IMD2020/1a8jd2/c8v2xno_0_mask.png
#   inflating: Master/IMD2020/1a8jd2/c8v5c8j_0.jpg
#   inflating: Master/IMD2020/1a8jd2/c8v5c8j_0_mask.png
#    creating: Master/IMD2020/1a9l4s/
#   inflating: Master/IMD2020/1a9l4s/1a9l4s_orig.jpg
#   inflating: Master/IMD2020/1a9l4s/c8vcovx_0.jpg
#   inflating: Master/IMD2020/1a9l4s/c8vcovx_0_mask.png
#   inflating: Master/IMD2020/1a9l4s/c8vemkb_0.jpg
#   inflating: Master/IMD2020/1a9l4s/c8vemkb_0_mask.png
#   inflating: Master/IMD2020/1a9l4s/c8venih_0.jpg
#   inflating: Master/IMD2020/1a9l4s/c8venih_0_mask.png
#   inflating: Master/IMD2020/1a9l4s/c8vepqy_0.jpg
#   inflating: Master/IMD2020/1a9l4s/c8vepqy_0_mask.png
#   inflating: Master/IMD2020/1a9l4s/c8vf42i_0.jpg
#   inflating: Master/IMD2020/1a9l4s/c8vf42i_0_mask.png
#   inflating: Master/IMD2020/1a9l4s/c8vfd6x_0.jpg
#   inflating: Master/IMD2020/1a9l4s/c8vfd6x_0_mask.png
#   inflating: Master/IMD2020/1a9l4s/c8vjlk1_0.jpg
#   inflating: Master/IMD2020/1a9l4s/c8vjlk1_0_mask.png
#   inflating: Master/IMD2020/1a9l4s/c8voq23_0.jpg
#   inflating: Master/IMD2020/1a9l4s/c8voq23_0_mask.png
#    creating: Master/IMD2020/1a9tss/
#   inflating: Master/IMD2020/1a9tss/1a9tss_orig.jpg
#   inflating: Master/IMD2020/1a9tss/c8vejd9_0.jpg
#   inflating: Master/IMD2020/1a9tss/c8vejd9_0_mask.png
#   inflating: Master/IMD2020/1a9tss/c8vi1sj_0.png
#   inflating: Master/IMD2020/1a9tss/c8vi1sj_0_mask.png
#   inflating: Master/IMD2020/1a9tss/c8vklwm_0.png
#   inflating: Master/IMD2020/1a9tss/c8vklwm_0_mask.png
#   inflating: Master/IMD2020/1a9tss/c8vm7al_0.jpg
#   inflating: Master/IMD2020/1a9tss/c8vm7al_0_mask.png
#   inflating: Master/IMD2020/1a9tss/c8vnyrx_0.jpg
#   inflating: Master/IMD2020/1a9tss/c8vnyrx_0_mask.png
#   inflating: Master/IMD2020/1a9tss/c8vqhe0_0.jpg
#   inflating: Master/IMD2020/1a9tss/c8vqhe0_0_mask.png
#    creating: Master/IMD2020/1a16mu/
#   inflating: Master/IMD2020/1a16mu/1a16mu_orig.jpg
#   inflating: Master/IMD2020/1a16mu/c8t64te_0.jpg
#   inflating: Master/IMD2020/1a16mu/c8t64te_0_mask.png
#   inflating: Master/IMD2020/1a16mu/c8t9rsw_0.jpg
#   inflating: Master/IMD2020/1a16mu/c8t9rsw_0_mask.png
#    creating: Master/IMD2020/1a41rr/
#   inflating: Master/IMD2020/1a41rr/1a41rr_orig.jpg
#   inflating: Master/IMD2020/1a41rr/c8ty2bs_0.jpg
#   inflating: Master/IMD2020/1a41rr/c8ty2bs_0_mask.png
#   inflating: Master/IMD2020/1a41rr/c8tzqf0_0.jpg
#   inflating: Master/IMD2020/1a41rr/c8tzqf0_0_mask.png
#    creating: Master/IMD2020/1a69n6/
#   inflating: Master/IMD2020/1a69n6/1a69n6_orig.jpg
#   inflating: Master/IMD2020/1a69n6/c8uka8j_0.jpg
#   inflating: Master/IMD2020/1a69n6/c8uka8j_0_mask.png
#   inflating: Master/IMD2020/1a69n6/c8ulbmf_0.jpg
#   inflating: Master/IMD2020/1a69n6/c8ulbmf_0_mask.png
#    creating: Master/IMD2020/1a84zh/
#   inflating: Master/IMD2020/1a84zh/1a84zh_orig.jpg
#   inflating: Master/IMD2020/1a84zh/c8v1094_0.png
#   inflating: Master/IMD2020/1a84zh/c8v1094_0_mask.png
#   inflating: Master/IMD2020/1a84zh/c8v26qj_0.png
#   inflating: Master/IMD2020/1a84zh/c8v26qj_0_mask.png
#   inflating: Master/IMD2020/1a84zh/c8v3tc5_0.png
#   inflating: Master/IMD2020/1a84zh/c8v3tc5_0_mask.png
#   inflating: Master/IMD2020/1a84zh/c8v3xty_0.jpg
#   inflating: Master/IMD2020/1a84zh/c8v3xty_0_mask.png
#   inflating: Master/IMD2020/1a84zh/c8v70y3_0.png
#   inflating: Master/IMD2020/1a84zh/c8v70y3_0_mask.png
#    creating: Master/IMD2020/1aa6sn/
#   inflating: Master/IMD2020/1aa6sn/1aa6sn_orig.jpg
#   inflating: Master/IMD2020/1aa6sn/c8vgphr_0.jpg
#   inflating: Master/IMD2020/1aa6sn/c8vgphr_0_mask.png
#    creating: Master/IMD2020/1aa8xl/
#   inflating: Master/IMD2020/1aa8xl/1aa8xl_orig.jpg
#   inflating: Master/IMD2020/1aa8xl/c8viohc_0.jpg
#   inflating: Master/IMD2020/1aa8xl/c8viohc_0_mask.png
#   inflating: Master/IMD2020/1aa8xl/c8vizkp_0.jpg
#   inflating: Master/IMD2020/1aa8xl/c8vizkp_0_mask.png
#   inflating: Master/IMD2020/1aa8xl/c8vkbiq_0.jpg
#   inflating: Master/IMD2020/1aa8xl/c8vkbiq_0_mask.png
#   inflating: Master/IMD2020/1aa8xl/c8vkf28_0.jpg
#   inflating: Master/IMD2020/1aa8xl/c8vkf28_0_mask.png
#   inflating: Master/IMD2020/1aa8xl/c8vo3wv_0.jpg
#   inflating: Master/IMD2020/1aa8xl/c8vo3wv_0_mask.png
#   inflating: Master/IMD2020/1aa8xl/c8vol8v_0.jpg
#   inflating: Master/IMD2020/1aa8xl/c8vol8v_0_mask.png
#   inflating: Master/IMD2020/1aa8xl/c8vpmfd_0.jpg
#   inflating: Master/IMD2020/1aa8xl/c8vpmfd_0_mask.png
#   inflating: Master/IMD2020/1aa8xl/c8vqeqw_0.jpg
#   inflating: Master/IMD2020/1aa8xl/c8vqeqw_0_mask.png
#    creating: Master/IMD2020/1aafqb/
#   inflating: Master/IMD2020/1aafqb/1aafqb_orig.jpg
#   inflating: Master/IMD2020/1aafqb/c8vkb96_0.jpg
#   inflating: Master/IMD2020/1aafqb/c8vkb96_0_mask.png
#    creating: Master/IMD2020/1ac1g7/
#   inflating: Master/IMD2020/1ac1g7/1ac1g7_orig.jpg
#   inflating: Master/IMD2020/1ac1g7/c8w0a7n_0.jpg
#   inflating: Master/IMD2020/1ac1g7/c8w0a7n_0_mask.png
#   inflating: Master/IMD2020/1ac1g7/c8w0r2r_0.jpg
#   inflating: Master/IMD2020/1ac1g7/c8w0r2r_0_mask.png
#   inflating: Master/IMD2020/1ac1g7/c8w0y2v_0.jpg
#   inflating: Master/IMD2020/1ac1g7/c8w0y2v_0_mask.png
#   inflating: Master/IMD2020/1ac1g7/c8w2mlr_0.jpg
#   inflating: Master/IMD2020/1ac1g7/c8w2mlr_0_mask.png
#   inflating: Master/IMD2020/1ac1g7/c8w5v0p_0.jpg
#   inflating: Master/IMD2020/1ac1g7/c8w5v0p_0_mask.png
#    creating: Master/IMD2020/1acw36/
#   inflating: Master/IMD2020/1acw36/1acw36_orig.jpg
#   inflating: Master/IMD2020/1acw36/c8wantc_0.jpg
#   inflating: Master/IMD2020/1acw36/c8wantc_0_mask.png
#   inflating: Master/IMD2020/1acw36/c8wbo4v_0.jpg
#   inflating: Master/IMD2020/1acw36/c8wbo4v_0_mask.png
#    creating: Master/IMD2020/1aczjh/
#   inflating: Master/IMD2020/1aczjh/1aczjh_orig.jpg
#   inflating: Master/IMD2020/1aczjh/c8w9n2q_0.png
#   inflating: Master/IMD2020/1aczjh/c8w9n2q_0_mask.png
#   inflating: Master/IMD2020/1aczjh/c8wars7_0.jpg
#   inflating: Master/IMD2020/1aczjh/c8wars7_0_mask.png
#    creating: Master/IMD2020/1ad1a0/
#   inflating: Master/IMD2020/1ad1a0/1ad1a0_orig.jpg
#   inflating: Master/IMD2020/1ad1a0/c8wc5ln_0.png
#   inflating: Master/IMD2020/1ad1a0/c8wc5ln_0_mask.png
#   inflating: Master/IMD2020/1ad1a0/c8wc6jq_0.png
#   inflating: Master/IMD2020/1ad1a0/c8wc6jq_0_mask.png
#   inflating: Master/IMD2020/1ad1a0/c8wc7vs_0.jpg
#   inflating: Master/IMD2020/1ad1a0/c8wc7vs_0_mask.png
#   inflating: Master/IMD2020/1ad1a0/c8wcbsq_0.jpg
#   inflating: Master/IMD2020/1ad1a0/c8wcbsq_0_mask.png
#   inflating: Master/IMD2020/1ad1a0/c8wcfx9_0.jpg
#   inflating: Master/IMD2020/1ad1a0/c8wcfx9_0_mask.png
#   inflating: Master/IMD2020/1ad1a0/c8wclzm_0.jpg
#   inflating: Master/IMD2020/1ad1a0/c8wclzm_0_mask.png
#   inflating: Master/IMD2020/1ad1a0/c8wcodr_0.jpg
#   inflating: Master/IMD2020/1ad1a0/c8wcodr_0_mask.png
#   inflating: Master/IMD2020/1ad1a0/c8wcpg5_0.png
#   inflating: Master/IMD2020/1ad1a0/c8wcpg5_0_mask.png
#   inflating: Master/IMD2020/1ad1a0/c8wdsc1_0.jpg
#   inflating: Master/IMD2020/1ad1a0/c8wdsc1_0_mask.png
#    creating: Master/IMD2020/1aeqsl/
#   inflating: Master/IMD2020/1aeqsl/1aeqsl_orig.jpg
#   inflating: Master/IMD2020/1aeqsl/c8wrczy_0.jpg
#   inflating: Master/IMD2020/1aeqsl/c8wrczy_0_mask.png
#   inflating: Master/IMD2020/1aeqsl/c8wrglm_0.jpg
#   inflating: Master/IMD2020/1aeqsl/c8wrglm_0_mask.png
#   inflating: Master/IMD2020/1aeqsl/c8wrw4f_0.jpg
#   inflating: Master/IMD2020/1aeqsl/c8wrw4f_0_mask.png
#   inflating: Master/IMD2020/1aeqsl/c8wsol6_0.jpg
#   inflating: Master/IMD2020/1aeqsl/c8wsol6_0_mask.png
#   inflating: Master/IMD2020/1aeqsl/c8wtc5y_0.jpg
#   inflating: Master/IMD2020/1aeqsl/c8wtc5y_0_mask.png
#   inflating: Master/IMD2020/1aeqsl/c8wtjmm_0.png
#   inflating: Master/IMD2020/1aeqsl/c8wtjmm_0_mask.png
#   inflating: Master/IMD2020/1aeqsl/c8wufvd_0.png
#   inflating: Master/IMD2020/1aeqsl/c8wufvd_0_mask.png
#   inflating: Master/IMD2020/1aeqsl/c8wuvts_0.png
#   inflating: Master/IMD2020/1aeqsl/c8wuvts_0_mask.png
#   inflating: Master/IMD2020/1aeqsl/c8x0x1t_0.jpg
#   inflating: Master/IMD2020/1aeqsl/c8x0x1t_0_mask.png
#    creating: Master/IMD2020/1aeur2/
#   inflating: Master/IMD2020/1aeur2/1aeur2_orig.jpg
#   inflating: Master/IMD2020/1aeur2/c8wry2k_0.jpg
#   inflating: Master/IMD2020/1aeur2/c8wry2k_0_mask.png
#   inflating: Master/IMD2020/1aeur2/c8wt4r2_0.jpg
#   inflating: Master/IMD2020/1aeur2/c8wt4r2_0_mask.png
#   inflating: Master/IMD2020/1aeur2/c8wte77_0.jpg
#   inflating: Master/IMD2020/1aeur2/c8wte77_0_mask.png
#    creating: Master/IMD2020/1af2jv/
#   inflating: Master/IMD2020/1af2jv/1af2jv_orig.jpg
#   inflating: Master/IMD2020/1af2jv/c8wu4jn_0.jpg
#   inflating: Master/IMD2020/1af2jv/c8wu4jn_0_mask.png
#    creating: Master/IMD2020/1af7t4/
#   inflating: Master/IMD2020/1af7t4/1af7t4_orig.jpg
#   inflating: Master/IMD2020/1af7t4/c8wvegs_0.jpg
#   inflating: Master/IMD2020/1af7t4/c8wvegs_0_mask.png
#   inflating: Master/IMD2020/1af7t4/c8wwgw2_0.jpg
#   inflating: Master/IMD2020/1af7t4/c8wwgw2_0_mask.png
#   inflating: Master/IMD2020/1af7t4/c8wwrie_0.jpg
#   inflating: Master/IMD2020/1af7t4/c8wwrie_0_mask.png
#   inflating: Master/IMD2020/1af7t4/c8wx8en_0.jpg
#   inflating: Master/IMD2020/1af7t4/c8wx8en_0_mask.png
#   inflating: Master/IMD2020/1af7t4/c8wz8qw_0.jpg
#   inflating: Master/IMD2020/1af7t4/c8wz8qw_0_mask.png
#   inflating: Master/IMD2020/1af7t4/c8wziyg_0.jpg
#   inflating: Master/IMD2020/1af7t4/c8wziyg_0_mask.png
#    creating: Master/IMD2020/1afc31/
#   inflating: Master/IMD2020/1afc31/1afc31_orig.jpg
#   inflating: Master/IMD2020/1afc31/c8wyxuh_0.jpg
#   inflating: Master/IMD2020/1afc31/c8wyxuh_0_mask.png
#    creating: Master/IMD2020/1afcns/
#   inflating: Master/IMD2020/1afcns/1afcns_orig.jpg
#   inflating: Master/IMD2020/1afcns/c8wxqdn_0.jpg
#   inflating: Master/IMD2020/1afcns/c8wxqdn_0_mask.png
#    creating: Master/IMD2020/1afv6o/
#   inflating: Master/IMD2020/1afv6o/1afv6o_orig.jpg
#   inflating: Master/IMD2020/1afv6o/c8x27kq_0.jpg
#   inflating: Master/IMD2020/1afv6o/c8x27kq_0_mask.png
#   inflating: Master/IMD2020/1afv6o/c8x3rcx_0.jpg
#   inflating: Master/IMD2020/1afv6o/c8x3rcx_0_mask.png
#    creating: Master/IMD2020/1afvdd/
#   inflating: Master/IMD2020/1afvdd/1afvdd_orig.jpg
#   inflating: Master/IMD2020/1afvdd/c8x1pe8_0.jpg
#   inflating: Master/IMD2020/1afvdd/c8x1pe8_0_mask.png
#   inflating: Master/IMD2020/1afvdd/c8x2s20_0.jpg
#   inflating: Master/IMD2020/1afvdd/c8x2s20_0_mask.png
#    creating: Master/IMD2020/1agrmz/
#   inflating: Master/IMD2020/1agrmz/1agrmz_orig.jpg
#   inflating: Master/IMD2020/1agrmz/c8x9xkj_0.jpg
#   inflating: Master/IMD2020/1agrmz/c8x9xkj_0_mask.png
#   inflating: Master/IMD2020/1agrmz/c8xa1qd_0.jpg
#   inflating: Master/IMD2020/1agrmz/c8xa1qd_0_mask.png
#   inflating: Master/IMD2020/1agrmz/c8xanp8_0.png
#   inflating: Master/IMD2020/1agrmz/c8xanp8_0_mask.png
#   inflating: Master/IMD2020/1agrmz/c8xariv_0.jpg
#   inflating: Master/IMD2020/1agrmz/c8xariv_0_mask.png
#   inflating: Master/IMD2020/1agrmz/c8xd6bv_0.jpg
#   inflating: Master/IMD2020/1agrmz/c8xd6bv_0_mask.png
#   inflating: Master/IMD2020/1agrmz/c8xdawa_0.jpg
#   inflating: Master/IMD2020/1agrmz/c8xdawa_0_mask.png
#    creating: Master/IMD2020/1agt1r/
#   inflating: Master/IMD2020/1agt1r/1agt1r_orig.jpg
#   inflating: Master/IMD2020/1agt1r/c8xbjz3_0.jpg
#   inflating: Master/IMD2020/1agt1r/c8xbjz3_0_mask.png
#    creating: Master/IMD2020/1ah0n7/
#   inflating: Master/IMD2020/1ah0n7/1ah0n7_orig.jpg
#   inflating: Master/IMD2020/1ah0n7/c8xfpsi_0.png
#   inflating: Master/IMD2020/1ah0n7/c8xfpsi_0_mask.png
#   inflating: Master/IMD2020/1ah0n7/c8xgdhj_0.jpg
#   inflating: Master/IMD2020/1ah0n7/c8xgdhj_0_mask.png
#    creating: Master/IMD2020/1ahawd/
#   inflating: Master/IMD2020/1ahawd/1ahawd_orig.jpg
#   inflating: Master/IMD2020/1ahawd/c8xgnf4_0.jpg
#   inflating: Master/IMD2020/1ahawd/c8xgnf4_0_mask.png
#   inflating: Master/IMD2020/1ahawd/c8xhzdr_0.jpg
#   inflating: Master/IMD2020/1ahawd/c8xhzdr_0_mask.png
#    creating: Master/IMD2020/1ahtfm/
#   inflating: Master/IMD2020/1ahtfm/1ahtfm_orig.jpg
#   inflating: Master/IMD2020/1ahtfm/c8xkcsl_0.jpg
#   inflating: Master/IMD2020/1ahtfm/c8xkcsl_0_mask.png
#    creating: Master/IMD2020/1aidqf/
#   inflating: Master/IMD2020/1aidqf/1aidqf_orig.jpg
#   inflating: Master/IMD2020/1aidqf/c8xtrds_0.jpg
#   inflating: Master/IMD2020/1aidqf/c8xtrds_0_mask.png
#   inflating: Master/IMD2020/1aidqf/c8xujpn_0.jpg
#   inflating: Master/IMD2020/1aidqf/c8xujpn_0_mask.png
#    creating: Master/IMD2020/1ajtpd/
#   inflating: Master/IMD2020/1ajtpd/1ajtpd_orig.jpg
#   inflating: Master/IMD2020/1ajtpd/c8y2qcw_0.jpg
#   inflating: Master/IMD2020/1ajtpd/c8y2qcw_0_mask.png
#   inflating: Master/IMD2020/1ajtpd/c8y2vvo_0.jpg
#   inflating: Master/IMD2020/1ajtpd/c8y2vvo_0_mask.png
#   inflating: Master/IMD2020/1ajtpd/c8y31sd_0.jpg
#   inflating: Master/IMD2020/1ajtpd/c8y31sd_0_mask.png
#   inflating: Master/IMD2020/1ajtpd/c8y3utt_0.jpg
#   inflating: Master/IMD2020/1ajtpd/c8y3utt_0_mask.png
#   inflating: Master/IMD2020/1ajtpd/c8y55d9_0.jpg
#   inflating: Master/IMD2020/1ajtpd/c8y55d9_0_mask.png
#   inflating: Master/IMD2020/1ajtpd/c8y5f1t_0.jpg
#   inflating: Master/IMD2020/1ajtpd/c8y5f1t_0_mask.png
#   inflating: Master/IMD2020/1ajtpd/c8y9zbo_0.jpg
#   inflating: Master/IMD2020/1ajtpd/c8y9zbo_0_mask.png
#   inflating: Master/IMD2020/1ajtpd/c8yaujz_0.jpg
#   inflating: Master/IMD2020/1ajtpd/c8yaujz_0_mask.png
#   inflating: Master/IMD2020/1ajtpd/c8yb71t_0.jpg
#   inflating: Master/IMD2020/1ajtpd/c8yb71t_0_mask.png
#   inflating: Master/IMD2020/1ajtpd/c8ybsvm_0.png
#   inflating: Master/IMD2020/1ajtpd/c8ybsvm_0_mask.png
#   inflating: Master/IMD2020/1ajtpd/c8yc2ry_0.jpg
#   inflating: Master/IMD2020/1ajtpd/c8yc2ry_0_mask.png
#   inflating: Master/IMD2020/1ajtpd/c8ydsfu_0.jpg
#   inflating: Master/IMD2020/1ajtpd/c8ydsfu_0_mask.png
#   inflating: Master/IMD2020/1ajtpd/c8ye71b_0.jpg
#   inflating: Master/IMD2020/1ajtpd/c8ye71b_0_mask.png
#    creating: Master/IMD2020/1al0z1/
#   inflating: Master/IMD2020/1al0z1/1al0z1_orig.jpg
#   inflating: Master/IMD2020/1al0z1/c8yea0e_0.jpg
#   inflating: Master/IMD2020/1al0z1/c8yea0e_0_mask.png
#   inflating: Master/IMD2020/1al0z1/c8yhi3a_0.jpg
#   inflating: Master/IMD2020/1al0z1/c8yhi3a_0_mask.png
#    creating: Master/IMD2020/1al8bl/
#   inflating: Master/IMD2020/1al8bl/1al8bl_orig.jpg
#   inflating: Master/IMD2020/1al8bl/c8yfhte_0.jpg
#   inflating: Master/IMD2020/1al8bl/c8yfhte_0_mask.png
#    creating: Master/IMD2020/1al8oy/
#   inflating: Master/IMD2020/1al8oy/1al8oy_orig.jpg
#   inflating: Master/IMD2020/1al8oy/c8yh8v9_0.jpg
#   inflating: Master/IMD2020/1al8oy/c8yh8v9_0_mask.png
#   inflating: Master/IMD2020/1al8oy/c8yhtxf_0.jpg
#   inflating: Master/IMD2020/1al8oy/c8yhtxf_0_mask.png
#   inflating: Master/IMD2020/1al8oy/c8yib78_0.png
#   inflating: Master/IMD2020/1al8oy/c8yib78_0_mask.png
#   inflating: Master/IMD2020/1al8oy/c8yipuf_0.jpg
#   inflating: Master/IMD2020/1al8oy/c8yipuf_0_mask.png
#   inflating: Master/IMD2020/1al8oy/c8yiqdr_0.jpg
#   inflating: Master/IMD2020/1al8oy/c8yiqdr_0_mask.png
#   inflating: Master/IMD2020/1al8oy/c8yj464_0.png
#   inflating: Master/IMD2020/1al8oy/c8yj464_0_mask.png
#   inflating: Master/IMD2020/1al8oy/c8yjs3y_0.jpg
#   inflating: Master/IMD2020/1al8oy/c8yjs3y_0_mask.png
#   inflating: Master/IMD2020/1al8oy/c8yjscj_0.png
#   inflating: Master/IMD2020/1al8oy/c8yjscj_0_mask.png
#   inflating: Master/IMD2020/1al8oy/c8yjv4u_0.jpg
#   inflating: Master/IMD2020/1al8oy/c8yjv4u_0_mask.png
#   inflating: Master/IMD2020/1al8oy/c8ynnae_0.jpg
#   inflating: Master/IMD2020/1al8oy/c8ynnae_0_mask.png
#    creating: Master/IMD2020/1alcdm/
#   inflating: Master/IMD2020/1alcdm/1alcdm_orig.jpg
#   inflating: Master/IMD2020/1alcdm/c8ypb15_0.jpg
#   inflating: Master/IMD2020/1alcdm/c8ypb15_0_mask.png
#    creating: Master/IMD2020/1am7zp/
#   inflating: Master/IMD2020/1am7zp/1am7zp_orig.jpg
#   inflating: Master/IMD2020/1am7zp/c8yqawk_0.png
#   inflating: Master/IMD2020/1am7zp/c8yqawk_0_mask.png
#    creating: Master/IMD2020/1amtqf/
#   inflating: Master/IMD2020/1amtqf/1amtqf_orig.jpg
#   inflating: Master/IMD2020/1amtqf/c8yv0ld_0.jpg
#   inflating: Master/IMD2020/1amtqf/c8yv0ld_0_mask.png
#   inflating: Master/IMD2020/1amtqf/c8yvmji_0.jpg
#   inflating: Master/IMD2020/1amtqf/c8yvmji_0_mask.png
#    creating: Master/IMD2020/1anhg4/
#   inflating: Master/IMD2020/1anhg4/1anhg4_orig.jpg
#   inflating: Master/IMD2020/1anhg4/c8z0zg4_0.jpg
#   inflating: Master/IMD2020/1anhg4/c8z0zg4_0_mask.png
#   inflating: Master/IMD2020/1anhg4/c8z1qqq_0.jpg
#   inflating: Master/IMD2020/1anhg4/c8z1qqq_0_mask.png
#   inflating: Master/IMD2020/1anhg4/c8z1ubs_0.jpg
#   inflating: Master/IMD2020/1anhg4/c8z1ubs_0_mask.png
#   inflating: Master/IMD2020/1anhg4/c8z2itj_0.jpg
#   inflating: Master/IMD2020/1anhg4/c8z2itj_0_mask.png
#   inflating: Master/IMD2020/1anhg4/c8zf0hg_0.jpg
#   inflating: Master/IMD2020/1anhg4/c8zf0hg_0_mask.png
#    creating: Master/IMD2020/1anq2a/
#   inflating: Master/IMD2020/1anq2a/1anq2a_orig.jpg
#   inflating: Master/IMD2020/1anq2a/c8z27jg_0.jpg
#   inflating: Master/IMD2020/1anq2a/c8z27jg_0_mask.png
#   inflating: Master/IMD2020/1anq2a/c8z31h1_0.jpg
#   inflating: Master/IMD2020/1anq2a/c8z31h1_0_mask.png
#   inflating: Master/IMD2020/1anq2a/c8z3et9_0.jpg
#   inflating: Master/IMD2020/1anq2a/c8z3et9_0_mask.png
#   inflating: Master/IMD2020/1anq2a/c8z3l9n_0.jpg
#   inflating: Master/IMD2020/1anq2a/c8z3l9n_0_mask.png
#   inflating: Master/IMD2020/1anq2a/c8z3m7v_0.jpg
#   inflating: Master/IMD2020/1anq2a/c8z3m7v_0_mask.png
#   inflating: Master/IMD2020/1anq2a/c8z3q6p_0.png
#   inflating: Master/IMD2020/1anq2a/c8z3q6p_0_mask.png
#   inflating: Master/IMD2020/1anq2a/c8z4ldo_0.jpg
#   inflating: Master/IMD2020/1anq2a/c8z4ldo_0_mask.png
#   inflating: Master/IMD2020/1anq2a/c8z4o30_0.jpg
#   inflating: Master/IMD2020/1anq2a/c8z4o30_0_mask.png
#   inflating: Master/IMD2020/1anq2a/c8z50ak_0.png
#   inflating: Master/IMD2020/1anq2a/c8z50ak_0_mask.png
#   inflating: Master/IMD2020/1anq2a/c8z82ta_0.jpg
#   inflating: Master/IMD2020/1anq2a/c8z82ta_0_mask.png
#   inflating: Master/IMD2020/1anq2a/c8zepg5_0.jpg
#   inflating: Master/IMD2020/1anq2a/c8zepg5_0_mask.png
#    creating: Master/IMD2020/1aohro/
#   inflating: Master/IMD2020/1aohro/1aohro_orig.jpg
#   inflating: Master/IMD2020/1aohro/c8zax0v_0.jpg
#   inflating: Master/IMD2020/1aohro/c8zax0v_0_mask.png
#   inflating: Master/IMD2020/1aohro/c8zb000_0.jpg
#   inflating: Master/IMD2020/1aohro/c8zb000_0_mask.png
#   inflating: Master/IMD2020/1aohro/c8zefoe_0.jpg
#   inflating: Master/IMD2020/1aohro/c8zefoe_0_mask.png
#   inflating: Master/IMD2020/1aohro/c8zexo2_0.jpg
#   inflating: Master/IMD2020/1aohro/c8zexo2_0_mask.png
#   inflating: Master/IMD2020/1aohro/c8zezwq_0.jpg
#   inflating: Master/IMD2020/1aohro/c8zezwq_0_mask.png
#   inflating: Master/IMD2020/1aohro/c8zg45r_0.jpg
#   inflating: Master/IMD2020/1aohro/c8zg45r_0_mask.png
#   inflating: Master/IMD2020/1aohro/c8zjhlp_0.jpg
#   inflating: Master/IMD2020/1aohro/c8zjhlp_0_mask.png
#    creating: Master/IMD2020/1aoxnt/
#   inflating: Master/IMD2020/1aoxnt/1aoxnt_orig.jpg
#   inflating: Master/IMD2020/1aoxnt/c8zijis_0.jpg
#   inflating: Master/IMD2020/1aoxnt/c8zijis_0_mask.png
#   inflating: Master/IMD2020/1aoxnt/c8zj217_0.jpg
#   inflating: Master/IMD2020/1aoxnt/c8zj217_0_mask.png
#   inflating: Master/IMD2020/1aoxnt/c8zj234_0.jpg
#   inflating: Master/IMD2020/1aoxnt/c8zj234_0_mask.png
#   inflating: Master/IMD2020/1aoxnt/c8zjp3h_0.jpg
#   inflating: Master/IMD2020/1aoxnt/c8zjp3h_0_mask.png
#   inflating: Master/IMD2020/1aoxnt/c8zmf37_0.jpg
#   inflating: Master/IMD2020/1aoxnt/c8zmf37_0_mask.png
#   inflating: Master/IMD2020/1aoxnt/c8zpxv6_0.jpg
#   inflating: Master/IMD2020/1aoxnt/c8zpxv6_0_mask.png
#    creating: Master/IMD2020/1apbp2/
#   inflating: Master/IMD2020/1apbp2/1apbp2_orig.jpg
#   inflating: Master/IMD2020/1apbp2/c8zkjgp_0.jpg
#   inflating: Master/IMD2020/1apbp2/c8zkjgp_0_mask.png
#    creating: Master/IMD2020/1aq0f0/
#   inflating: Master/IMD2020/1aq0f0/1aq0f0_orig.jpg
#   inflating: Master/IMD2020/1aq0f0/c8zp10g_0.jpg
#   inflating: Master/IMD2020/1aq0f0/c8zp10g_0_mask.png
#   inflating: Master/IMD2020/1aq0f0/c8zv3tl_0.jpg
#   inflating: Master/IMD2020/1aq0f0/c8zv3tl_0_mask.png
#    creating: Master/IMD2020/1aq6ym/
#   inflating: Master/IMD2020/1aq6ym/1aq6ym_orig.jpg
#   inflating: Master/IMD2020/1aq6ym/c8zqh4c_0.jpg
#   inflating: Master/IMD2020/1aq6ym/c8zqh4c_0_mask.png
#   inflating: Master/IMD2020/1aq6ym/c8zsg4j_0.jpg
#   inflating: Master/IMD2020/1aq6ym/c8zsg4j_0_mask.png
#   inflating: Master/IMD2020/1aq6ym/c8zsnr4_0.png
#   inflating: Master/IMD2020/1aq6ym/c8zsnr4_0_mask.png
#   inflating: Master/IMD2020/1aq6ym/c8zstoa_0.jpg
#   inflating: Master/IMD2020/1aq6ym/c8zstoa_0_mask.png
#   inflating: Master/IMD2020/1aq6ym/c8zt718_0.png
#   inflating: Master/IMD2020/1aq6ym/c8zt718_0_mask.png
#   inflating: Master/IMD2020/1aq6ym/c8zta7f_0.jpg
#   inflating: Master/IMD2020/1aq6ym/c8zta7f_0_mask.png
#   inflating: Master/IMD2020/1aq6ym/c8ztmnk_0.jpg
#   inflating: Master/IMD2020/1aq6ym/c8ztmnk_0_mask.png
#   inflating: Master/IMD2020/1aq6ym/c8zttpz_0.png
#   inflating: Master/IMD2020/1aq6ym/c8zttpz_0_mask.png
#   inflating: Master/IMD2020/1aq6ym/c8ztu03_0.jpg
#   inflating: Master/IMD2020/1aq6ym/c8ztu03_0_mask.png
#   inflating: Master/IMD2020/1aq6ym/c8zuhhz_0.jpg
#   inflating: Master/IMD2020/1aq6ym/c8zuhhz_0_mask.png
#   inflating: Master/IMD2020/1aq6ym/c8zvzmp_0.jpg
#   inflating: Master/IMD2020/1aq6ym/c8zvzmp_0_mask.png
#   inflating: Master/IMD2020/1aq6ym/c8zw8i7_0.jpg
#   inflating: Master/IMD2020/1aq6ym/c8zw8i7_0_mask.png
#   inflating: Master/IMD2020/1aq6ym/c8zwpv6_0.jpg
#   inflating: Master/IMD2020/1aq6ym/c8zwpv6_0_mask.png
#   inflating: Master/IMD2020/1aq6ym/c8zymv9_0.jpg
#   inflating: Master/IMD2020/1aq6ym/c8zymv9_0_mask.png
#   inflating: Master/IMD2020/1aq6ym/c9026js_0.jpg
#   inflating: Master/IMD2020/1aq6ym/c9026js_0_mask.png
#   inflating: Master/IMD2020/1aq6ym/c90580v_0.jpg
#   inflating: Master/IMD2020/1aq6ym/c90580v_0_mask.png
#    creating: Master/IMD2020/1aqi3j/
#   inflating: Master/IMD2020/1aqi3j/1aqi3j_orig.jpg
#   inflating: Master/IMD2020/1aqi3j/c8zu1fj_0.jpg
#   inflating: Master/IMD2020/1aqi3j/c8zu1fj_0_mask.png
#    creating: Master/IMD2020/1as2hj/
#   inflating: Master/IMD2020/1as2hj/1as2hj_orig.jpg
#   inflating: Master/IMD2020/1as2hj/c908yxz_0.jpg
#   inflating: Master/IMD2020/1as2hj/c908yxz_0_mask.png
#   inflating: Master/IMD2020/1as2hj/c909zbe_0.jpg
#   inflating: Master/IMD2020/1as2hj/c909zbe_0_mask.png
#   inflating: Master/IMD2020/1as2hj/c90g2uu_0.jpg
#   inflating: Master/IMD2020/1as2hj/c90g2uu_0_mask.png
#    creating: Master/IMD2020/1as3ai/
#   inflating: Master/IMD2020/1as3ai/1as3ai_orig.jpg
#   inflating: Master/IMD2020/1as3ai/c908vvn_0.jpg
#   inflating: Master/IMD2020/1as3ai/c908vvn_0_mask.png
#   inflating: Master/IMD2020/1as3ai/c90c2o3_0.jpg
#   inflating: Master/IMD2020/1as3ai/c90c2o3_0_mask.png
#   inflating: Master/IMD2020/1as3ai/c90c412_0.jpg
#   inflating: Master/IMD2020/1as3ai/c90c412_0_mask.png
#   inflating: Master/IMD2020/1as3ai/c90d7x7_0.jpg
#   inflating: Master/IMD2020/1as3ai/c90d7x7_0_mask.png
#   inflating: Master/IMD2020/1as3ai/c90d9fr_0.jpg
#   inflating: Master/IMD2020/1as3ai/c90d9fr_0_mask.png
#   inflating: Master/IMD2020/1as3ai/c90dutg_0.jpg
#   inflating: Master/IMD2020/1as3ai/c90dutg_0_mask.png
#   inflating: Master/IMD2020/1as3ai/c90ef5n_0.jpg
#   inflating: Master/IMD2020/1as3ai/c90ef5n_0_mask.png
#   inflating: Master/IMD2020/1as3ai/c90fxcd_0.jpg
#   inflating: Master/IMD2020/1as3ai/c90fxcd_0_mask.png
#   inflating: Master/IMD2020/1as3ai/c90hy8l_0.jpg
#   inflating: Master/IMD2020/1as3ai/c90hy8l_0_mask.png
#   inflating: Master/IMD2020/1as3ai/c90i4n3_0.jpg
#   inflating: Master/IMD2020/1as3ai/c90i4n3_0_mask.png
#   inflating: Master/IMD2020/1as3ai/c90lr6w_0.jpg
#   inflating: Master/IMD2020/1as3ai/c90lr6w_0_mask.png
#   inflating: Master/IMD2020/1as3ai/c90oh9u_0.jpg
#   inflating: Master/IMD2020/1as3ai/c90oh9u_0_mask.png
#    creating: Master/IMD2020/1as9ik/
#   inflating: Master/IMD2020/1as9ik/1as9ik_orig.jpg
#   inflating: Master/IMD2020/1as9ik/c90ciwt_0.png
#   inflating: Master/IMD2020/1as9ik/c90ciwt_0_mask.png
#   inflating: Master/IMD2020/1as9ik/c90cmeo_0.jpg
#   inflating: Master/IMD2020/1as9ik/c90cmeo_0_mask.png
#   inflating: Master/IMD2020/1as9ik/c90coip_0.jpg
#   inflating: Master/IMD2020/1as9ik/c90coip_0_mask.png
#   inflating: Master/IMD2020/1as9ik/c90cqnr_0.jpg
#   inflating: Master/IMD2020/1as9ik/c90cqnr_0_mask.png
#   inflating: Master/IMD2020/1as9ik/c90dflh_0.jpg
#   inflating: Master/IMD2020/1as9ik/c90dflh_0_mask.png
#   inflating: Master/IMD2020/1as9ik/c90do08_0.jpg
#   inflating: Master/IMD2020/1as9ik/c90do08_0_mask.png
#   inflating: Master/IMD2020/1as9ik/c90eken_0.jpg
#   inflating: Master/IMD2020/1as9ik/c90eken_0_mask.png
#   inflating: Master/IMD2020/1as9ik/c90g14e_0.jpg
#   inflating: Master/IMD2020/1as9ik/c90g14e_0_mask.png
#   inflating: Master/IMD2020/1as9ik/c90nr8m_0.jpg
#   inflating: Master/IMD2020/1as9ik/c90nr8m_0_mask.png
#    creating: Master/IMD2020/1asnfa/
#   inflating: Master/IMD2020/1asnfa/1asnfa_orig.jpg
#   inflating: Master/IMD2020/1asnfa/c90dujh_0.jpg
#   inflating: Master/IMD2020/1asnfa/c90dujh_0_mask.png
#    creating: Master/IMD2020/1at8em/
#   inflating: Master/IMD2020/1at8em/1at8em_orig.jpg
#   inflating: Master/IMD2020/1at8em/c90jgir_0.jpg
#   inflating: Master/IMD2020/1at8em/c90jgir_0_mask.png
#   inflating: Master/IMD2020/1at8em/c90n1qm_0.jpg
#   inflating: Master/IMD2020/1at8em/c90n1qm_0_mask.png
#   inflating: Master/IMD2020/1at8em/c90o4ei_0.jpg
#   inflating: Master/IMD2020/1at8em/c90o4ei_0_mask.png
#   inflating: Master/IMD2020/1at8em/c90s0h8_0.jpg
#   inflating: Master/IMD2020/1at8em/c90s0h8_0_mask.png
#    creating: Master/IMD2020/1atc54/
#   inflating: Master/IMD2020/1atc54/1atc54_orig.jpg
#   inflating: Master/IMD2020/1atc54/c90k1ai_0.jpg
#   inflating: Master/IMD2020/1atc54/c90k1ai_0_mask.png
#    creating: Master/IMD2020/1atm1o/
#   inflating: Master/IMD2020/1atm1o/1atm1o_orig.jpg
#   inflating: Master/IMD2020/1atm1o/c90mtx6_0.jpg
#   inflating: Master/IMD2020/1atm1o/c90mtx6_0_mask.png
#   inflating: Master/IMD2020/1atm1o/c90o79c_0.jpg
#   inflating: Master/IMD2020/1atm1o/c90o79c_0_mask.png
#   inflating: Master/IMD2020/1atm1o/c90okur_0.jpg
#   inflating: Master/IMD2020/1atm1o/c90okur_0_mask.png
#   inflating: Master/IMD2020/1atm1o/c90omlo_0.jpg
#   inflating: Master/IMD2020/1atm1o/c90omlo_0_mask.png
#   inflating: Master/IMD2020/1atm1o/c90os5y_0.jpg
#   inflating: Master/IMD2020/1atm1o/c90os5y_0_mask.png
#   inflating: Master/IMD2020/1atm1o/c90prjy_0.jpg
#   inflating: Master/IMD2020/1atm1o/c90prjy_0_mask.png
#   inflating: Master/IMD2020/1atm1o/c90pt3k_0.jpg
#   inflating: Master/IMD2020/1atm1o/c90pt3k_0_mask.png
#   inflating: Master/IMD2020/1atm1o/c90q0i2_0.jpg
#   inflating: Master/IMD2020/1atm1o/c90q0i2_0_mask.png
#   inflating: Master/IMD2020/1atm1o/c90q79y_0.jpg
#   inflating: Master/IMD2020/1atm1o/c90q79y_0_mask.png
#   inflating: Master/IMD2020/1atm1o/c90ra8t_0.jpg
#   inflating: Master/IMD2020/1atm1o/c90ra8t_0_mask.png
#   inflating: Master/IMD2020/1atm1o/c90rlp6_0.jpg
#   inflating: Master/IMD2020/1atm1o/c90rlp6_0_mask.png
#   inflating: Master/IMD2020/1atm1o/c90sb3t_0.jpg
#   inflating: Master/IMD2020/1atm1o/c90sb3t_0_mask.png
#   inflating: Master/IMD2020/1atm1o/c90sp6y_0.jpg
#   inflating: Master/IMD2020/1atm1o/c90sp6y_0_mask.png
#    creating: Master/IMD2020/1aty89/
#   inflating: Master/IMD2020/1aty89/1aty89_orig.jpg
#   inflating: Master/IMD2020/1aty89/c90pv3g_0.png
#   inflating: Master/IMD2020/1aty89/c90pv3g_0_mask.png
#    creating: Master/IMD2020/1aut4s/
#   inflating: Master/IMD2020/1aut4s/1aut4s_orig.jpg
#   inflating: Master/IMD2020/1aut4s/c90xtlr_0.png
#   inflating: Master/IMD2020/1aut4s/c90xtlr_0_mask.png
#   inflating: Master/IMD2020/1aut4s/c90yb6c_0.jpg
#   inflating: Master/IMD2020/1aut4s/c90yb6c_0_mask.png
#   inflating: Master/IMD2020/1aut4s/c90z7wb_0.png
#   inflating: Master/IMD2020/1aut4s/c90z7wb_0_mask.png
#   inflating: Master/IMD2020/1aut4s/c90zh16_0.jpg
#   inflating: Master/IMD2020/1aut4s/c90zh16_0_mask.png
#   inflating: Master/IMD2020/1aut4s/c90zhs7_0.jpg
#   inflating: Master/IMD2020/1aut4s/c90zhs7_0_mask.png
#   inflating: Master/IMD2020/1aut4s/c90znhl_0.jpg
#   inflating: Master/IMD2020/1aut4s/c90znhl_0_mask.png
#   inflating: Master/IMD2020/1aut4s/c90znpe_0.jpg
#   inflating: Master/IMD2020/1aut4s/c90znpe_0_mask.png
#   inflating: Master/IMD2020/1aut4s/c910bn6_0.jpg
#   inflating: Master/IMD2020/1aut4s/c910bn6_0_mask.png
#   inflating: Master/IMD2020/1aut4s/c910i2y_0.jpg
#   inflating: Master/IMD2020/1aut4s/c910i2y_0_mask.png
#   inflating: Master/IMD2020/1aut4s/c910wxp_0.jpg
#   inflating: Master/IMD2020/1aut4s/c910wxp_0_mask.png
#   inflating: Master/IMD2020/1aut4s/c911e7z_0.jpg
#   inflating: Master/IMD2020/1aut4s/c911e7z_0_mask.png
#   inflating: Master/IMD2020/1aut4s/c911vlp_0.jpg
#   inflating: Master/IMD2020/1aut4s/c911vlp_0_mask.png
#   inflating: Master/IMD2020/1aut4s/c912un2_0.jpg
#   inflating: Master/IMD2020/1aut4s/c912un2_0_mask.png
#   inflating: Master/IMD2020/1aut4s/c912yu8_0.jpg
#   inflating: Master/IMD2020/1aut4s/c912yu8_0_mask.png
#   inflating: Master/IMD2020/1aut4s/c9132um_0.jpg
#   inflating: Master/IMD2020/1aut4s/c9132um_0_mask.png
#   inflating: Master/IMD2020/1aut4s/c91338s_0.jpg
#   inflating: Master/IMD2020/1aut4s/c91338s_0_mask.png
#   inflating: Master/IMD2020/1aut4s/c91416c_0.jpg
#   inflating: Master/IMD2020/1aut4s/c91416c_0_mask.png
#   inflating: Master/IMD2020/1aut4s/c91681h_0.jpg
#   inflating: Master/IMD2020/1aut4s/c91681h_0_mask.png
#   inflating: Master/IMD2020/1aut4s/c9187tg_0.jpg
#   inflating: Master/IMD2020/1aut4s/c9187tg_0_mask.png
#   inflating: Master/IMD2020/1aut4s/c919ztm_0.jpg
#   inflating: Master/IMD2020/1aut4s/c919ztm_0_mask.png
#    creating: Master/IMD2020/1avax4/
#   inflating: Master/IMD2020/1avax4/1avax4_orig.jpg
#   inflating: Master/IMD2020/1avax4/c9163k4_0.jpg
#   inflating: Master/IMD2020/1avax4/c9163k4_0_mask.png
#    creating: Master/IMD2020/1awo2u/
#   inflating: Master/IMD2020/1awo2u/1awo2u_orig.jpg
#   inflating: Master/IMD2020/1awo2u/c91g223_0.jpg
#   inflating: Master/IMD2020/1awo2u/c91g223_0_mask.png
#    creating: Master/IMD2020/1awq0s/
#   inflating: Master/IMD2020/1awq0s/1awq0s_orig.jpg
#   inflating: Master/IMD2020/1awq0s/c91g0zs_0.jpg
#   inflating: Master/IMD2020/1awq0s/c91g0zs_0_mask.png
#   inflating: Master/IMD2020/1awq0s/c91gqec_0.jpg
#   inflating: Master/IMD2020/1awq0s/c91gqec_0_mask.png
#   inflating: Master/IMD2020/1awq0s/c91gxlz_0.jpg
#   inflating: Master/IMD2020/1awq0s/c91gxlz_0_mask.png
#   inflating: Master/IMD2020/1awq0s/c91h8oi_0.jpg
#   inflating: Master/IMD2020/1awq0s/c91h8oi_0_mask.png
#   inflating: Master/IMD2020/1awq0s/c91hclm_0.jpg
#   inflating: Master/IMD2020/1awq0s/c91hclm_0_mask.png
#   inflating: Master/IMD2020/1awq0s/c91lxbv_0.jpg
#   inflating: Master/IMD2020/1awq0s/c91lxbv_0_mask.png
#    creating: Master/IMD2020/1aws4w/
#   inflating: Master/IMD2020/1aws4w/1aws4w_orig.jpg
#   inflating: Master/IMD2020/1aws4w/c91h0oh_0.png
#   inflating: Master/IMD2020/1aws4w/c91h0oh_0_mask.png
#   inflating: Master/IMD2020/1aws4w/c91js2j_0.jpg
#   inflating: Master/IMD2020/1aws4w/c91js2j_0_mask.png
#    creating: Master/IMD2020/1awxvm/
#   inflating: Master/IMD2020/1awxvm/1awxvm_orig.jpg
#   inflating: Master/IMD2020/1awxvm/c91kvfk_0.jpg
#   inflating: Master/IMD2020/1awxvm/c91kvfk_0_mask.png
#   inflating: Master/IMD2020/1awxvm/c91lgra_0.jpg
#   inflating: Master/IMD2020/1awxvm/c91lgra_0_mask.png
#   inflating: Master/IMD2020/1awxvm/c91mttb_0.png
#   inflating: Master/IMD2020/1awxvm/c91mttb_0_mask.png
#   inflating: Master/IMD2020/1awxvm/c91nl9x_0.jpg
#   inflating: Master/IMD2020/1awxvm/c91nl9x_0_mask.png
#   inflating: Master/IMD2020/1awxvm/c91o1ca_0.jpg
#   inflating: Master/IMD2020/1awxvm/c91o1ca_0_mask.png
#   inflating: Master/IMD2020/1awxvm/c91oecj_0.jpg
#   inflating: Master/IMD2020/1awxvm/c91oecj_0_mask.png
#   inflating: Master/IMD2020/1awxvm/c91ot4e_0.jpg
#   inflating: Master/IMD2020/1awxvm/c91ot4e_0_mask.png
#   inflating: Master/IMD2020/1awxvm/c91qncg_0.jpg
#   inflating: Master/IMD2020/1awxvm/c91qncg_0_mask.png
#   inflating: Master/IMD2020/1awxvm/c91t61z_0.jpg
#   inflating: Master/IMD2020/1awxvm/c91t61z_0_mask.png
#    creating: Master/IMD2020/1ax6zq/
#   inflating: Master/IMD2020/1ax6zq/1ax6zq_orig.jpg
#   inflating: Master/IMD2020/1ax6zq/c91o8wl_0.jpg
#   inflating: Master/IMD2020/1ax6zq/c91o8wl_0_mask.png
#   inflating: Master/IMD2020/1ax6zq/c91pkp5_0.jpg
#   inflating: Master/IMD2020/1ax6zq/c91pkp5_0_mask.png
#    creating: Master/IMD2020/1axap9/
#   inflating: Master/IMD2020/1axap9/1axap9_orig.jpg
#   inflating: Master/IMD2020/1axap9/c91tgga_0.jpg
#   inflating: Master/IMD2020/1axap9/c91tgga_0_mask.png
#    creating: Master/IMD2020/1axr5s/
#   inflating: Master/IMD2020/1axr5s/1axr5s_orig.jpg
#   inflating: Master/IMD2020/1axr5s/c91s2tg_0.jpg
#   inflating: Master/IMD2020/1axr5s/c91s2tg_0_mask.png
#    creating: Master/IMD2020/1ay6i0/
#   inflating: Master/IMD2020/1ay6i0/1ay6i0_orig.jpg
#   inflating: Master/IMD2020/1ay6i0/c91ujvf_0.jpg
#   inflating: Master/IMD2020/1ay6i0/c91ujvf_0_mask.png
#   inflating: Master/IMD2020/1ay6i0/c91wof4_0.jpg
#   inflating: Master/IMD2020/1ay6i0/c91wof4_0_mask.png
#   inflating: Master/IMD2020/1ay6i0/c91x9y7_0.jpg
#   inflating: Master/IMD2020/1ay6i0/c91x9y7_0_mask.png
#   inflating: Master/IMD2020/1ay6i0/c923dj8_0.jpg
#   inflating: Master/IMD2020/1ay6i0/c923dj8_0_mask.png
#    creating: Master/IMD2020/1ayilh/
#   inflating: Master/IMD2020/1ayilh/1ayilh_orig.jpg
#   inflating: Master/IMD2020/1ayilh/c91z2wh_0.jpg
#   inflating: Master/IMD2020/1ayilh/c91z2wh_0_mask.png
#    creating: Master/IMD2020/1az3z4/
#   inflating: Master/IMD2020/1az3z4/1az3z4_orig.jpg
#   inflating: Master/IMD2020/1az3z4/c925i21_0.jpg
#   inflating: Master/IMD2020/1az3z4/c925i21_0_mask.png
#   inflating: Master/IMD2020/1az3z4/c9266q1_0.jpg
#   inflating: Master/IMD2020/1az3z4/c9266q1_0_mask.png
#   inflating: Master/IMD2020/1az3z4/c928dvs_0.jpg
#   inflating: Master/IMD2020/1az3z4/c928dvs_0_mask.png
#   inflating: Master/IMD2020/1az3z4/c928z82_0.jpg
#   inflating: Master/IMD2020/1az3z4/c928z82_0_mask.png
#   inflating: Master/IMD2020/1az3z4/c92atfy_0.jpg
#   inflating: Master/IMD2020/1az3z4/c92atfy_0_mask.png
#   inflating: Master/IMD2020/1az3z4/c92cabj_0.jpg
#   inflating: Master/IMD2020/1az3z4/c92cabj_0_mask.png
#   inflating: Master/IMD2020/1az3z4/c92cbi6_0.jpg
#   inflating: Master/IMD2020/1az3z4/c92cbi6_0_mask.png
#   inflating: Master/IMD2020/1az3z4/c92cltu_0.jpg
#   inflating: Master/IMD2020/1az3z4/c92cltu_0_mask.png
#   inflating: Master/IMD2020/1az3z4/c92coio_0.jpg
#   inflating: Master/IMD2020/1az3z4/c92coio_0_mask.png
#   inflating: Master/IMD2020/1az3z4/c92gvqy_0.jpg
#   inflating: Master/IMD2020/1az3z4/c92gvqy_0_mask.png
#    creating: Master/IMD2020/1azcvv/
#   inflating: Master/IMD2020/1azcvv/1azcvv_orig.jpg
#   inflating: Master/IMD2020/1azcvv/c926it4_0.jpg
#   inflating: Master/IMD2020/1azcvv/c926it4_0_mask.png
#   inflating: Master/IMD2020/1azcvv/c929k2x_0.jpg
#   inflating: Master/IMD2020/1azcvv/c929k2x_0_mask.png
#   inflating: Master/IMD2020/1azcvv/c92b5tv_0.jpg
#   inflating: Master/IMD2020/1azcvv/c92b5tv_0_mask.png
#   inflating: Master/IMD2020/1azcvv/c92be1o_0.jpg
#   inflating: Master/IMD2020/1azcvv/c92be1o_0_mask.png
#   inflating: Master/IMD2020/1azcvv/c92ebc2_0.jpg
#   inflating: Master/IMD2020/1azcvv/c92ebc2_0_mask.png
#   inflating: Master/IMD2020/1azcvv/c92eu2z_0.jpg
#   inflating: Master/IMD2020/1azcvv/c92eu2z_0_mask.png
#   inflating: Master/IMD2020/1azcvv/c92fby0_0.jpg
#   inflating: Master/IMD2020/1azcvv/c92fby0_0_mask.png
#    creating: Master/IMD2020/1azhe4/
#   inflating: Master/IMD2020/1azhe4/1azhe4_orig.jpg
#   inflating: Master/IMD2020/1azhe4/c928p9k_0.png
#   inflating: Master/IMD2020/1azhe4/c928p9k_0_mask.png
#   inflating: Master/IMD2020/1azhe4/c92dfhw_0.jpg
#   inflating: Master/IMD2020/1azhe4/c92dfhw_0_mask.png
#   inflating: Master/IMD2020/1azhe4/c92dy1z_0.jpg
#   inflating: Master/IMD2020/1azhe4/c92dy1z_0_mask.png
#   inflating: Master/IMD2020/1azhe4/c92glob_0.jpg
#   inflating: Master/IMD2020/1azhe4/c92glob_0_mask.png
#   inflating: Master/IMD2020/1azhe4/c92gt3h_0.jpg
#   inflating: Master/IMD2020/1azhe4/c92gt3h_0_mask.png
#   inflating: Master/IMD2020/1azhe4/c92hsr5_0.jpg
#   inflating: Master/IMD2020/1azhe4/c92hsr5_0_mask.png
#   inflating: Master/IMD2020/1azhe4/c92m6qm_0.png
#   inflating: Master/IMD2020/1azhe4/c92m6qm_0_mask.png
#    creating: Master/IMD2020/1aziip/
#   inflating: Master/IMD2020/1aziip/1aziip_orig.jpg
#   inflating: Master/IMD2020/1aziip/c92ai3g_0.png
#   inflating: Master/IMD2020/1aziip/c92ai3g_0_mask.png
#    creating: Master/IMD2020/1azovt/
#   inflating: Master/IMD2020/1azovt/1azovt_orig.jpg
#   inflating: Master/IMD2020/1azovt/c92ansy_0.jpg
#   inflating: Master/IMD2020/1azovt/c92ansy_0_mask.png
#   inflating: Master/IMD2020/1azovt/c92dxhr_0.jpg
#   inflating: Master/IMD2020/1azovt/c92dxhr_0_mask.png
#    creating: Master/IMD2020/1azru8/
#   inflating: Master/IMD2020/1azru8/1azru8_orig.jpg
#   inflating: Master/IMD2020/1azru8/c929r39_0.jpg
#   inflating: Master/IMD2020/1azru8/c929r39_0_mask.png
#   inflating: Master/IMD2020/1azru8/c92a3eh_0.jpg
#   inflating: Master/IMD2020/1azru8/c92a3eh_0_mask.png
#   inflating: Master/IMD2020/1azru8/c92df1g_0.jpg
#   inflating: Master/IMD2020/1azru8/c92df1g_0_mask.png
#   inflating: Master/IMD2020/1azru8/c92jm4u_0.jpg
#   inflating: Master/IMD2020/1azru8/c92jm4u_0_mask.png
#   inflating: Master/IMD2020/1azru8/c92lydr_0.jpg
#   inflating: Master/IMD2020/1azru8/c92lydr_0_mask.png
#    creating: Master/IMD2020/1azvyy/
#   inflating: Master/IMD2020/1azvyy/1azvyy_orig.jpg
#   inflating: Master/IMD2020/1azvyy/c92dgp0_0.jpg
#   inflating: Master/IMD2020/1azvyy/c92dgp0_0_mask.png
#    creating: Master/IMD2020/1b0kjn/
#   inflating: Master/IMD2020/1b0kjn/1b0kjn_orig.jpg
#   inflating: Master/IMD2020/1b0kjn/c92hrf9_0.jpg
#   inflating: Master/IMD2020/1b0kjn/c92hrf9_0_mask.png
#    creating: Master/IMD2020/1b1epd/
#   inflating: Master/IMD2020/1b1epd/1b1epd_orig.jpg
#   inflating: Master/IMD2020/1b1epd/c92q0yd_0.jpg
#   inflating: Master/IMD2020/1b1epd/c92q0yd_0_mask.png
#   inflating: Master/IMD2020/1b1epd/c92q18a_0.jpg
#   inflating: Master/IMD2020/1b1epd/c92q18a_0_mask.png
#   inflating: Master/IMD2020/1b1epd/c92q4n1_0.jpg
#   inflating: Master/IMD2020/1b1epd/c92q4n1_0_mask.png
#   inflating: Master/IMD2020/1b1epd/c92qfqu_0.png
#   inflating: Master/IMD2020/1b1epd/c92qfqu_0_mask.png
#   inflating: Master/IMD2020/1b1epd/c92qgq8_0.jpg
#   inflating: Master/IMD2020/1b1epd/c92qgq8_0_mask.png
#   inflating: Master/IMD2020/1b1epd/c92qy35_0.png
#   inflating: Master/IMD2020/1b1epd/c92qy35_0_mask.png
#   inflating: Master/IMD2020/1b1epd/c92v7b9_0.jpg
#   inflating: Master/IMD2020/1b1epd/c92v7b9_0_mask.png
#   inflating: Master/IMD2020/1b1epd/c92wo0u_0.jpg
#   inflating: Master/IMD2020/1b1epd/c92wo0u_0_mask.png
#   inflating: Master/IMD2020/1b1epd/c92zq41_0.jpg
#   inflating: Master/IMD2020/1b1epd/c92zq41_0_mask.png
#   inflating: Master/IMD2020/1b1epd/c930c3q_0.jpg
#   inflating: Master/IMD2020/1b1epd/c930c3q_0_mask.png
#    creating: Master/IMD2020/1b1pdg/
#   inflating: Master/IMD2020/1b1pdg/1b1pdg_orig.jpg
#   inflating: Master/IMD2020/1b1pdg/c92s0oq_0.jpg
#   inflating: Master/IMD2020/1b1pdg/c92s0oq_0_mask.png
#   inflating: Master/IMD2020/1b1pdg/c92s1zk_0.jpg
#   inflating: Master/IMD2020/1b1pdg/c92s1zk_0_mask.png
#   inflating: Master/IMD2020/1b1pdg/c92us74_0.jpg
#   inflating: Master/IMD2020/1b1pdg/c92us74_0_mask.png
#   inflating: Master/IMD2020/1b1pdg/c92vi3h_0.png
#   inflating: Master/IMD2020/1b1pdg/c92vi3h_0_mask.png
#   inflating: Master/IMD2020/1b1pdg/c92vzrm_0.jpg
#   inflating: Master/IMD2020/1b1pdg/c92vzrm_0_mask.png
#   inflating: Master/IMD2020/1b1pdg/c92xk95_0.jpg
#   inflating: Master/IMD2020/1b1pdg/c92xk95_0_mask.png
#    creating: Master/IMD2020/1b1vqv/
#   inflating: Master/IMD2020/1b1vqv/1b1vqv_orig.jpg
#   inflating: Master/IMD2020/1b1vqv/c92va3t_0.jpg
#   inflating: Master/IMD2020/1b1vqv/c92va3t_0_mask.png
#   inflating: Master/IMD2020/1b1vqv/c92wjsi_0.jpg
#   inflating: Master/IMD2020/1b1vqv/c92wjsi_0_mask.png
#    creating: Master/IMD2020/1b2ynb/
#   inflating: Master/IMD2020/1b2ynb/1b2ynb_orig.jpg
#   inflating: Master/IMD2020/1b2ynb/c933r08_0.jpg
#   inflating: Master/IMD2020/1b2ynb/c933r08_0_mask.png
#   inflating: Master/IMD2020/1b2ynb/c934im7_0.jpg
#   inflating: Master/IMD2020/1b2ynb/c934im7_0_mask.png
#   inflating: Master/IMD2020/1b2ynb/c9350xa_0.jpg
#   inflating: Master/IMD2020/1b2ynb/c9350xa_0_mask.png
#   inflating: Master/IMD2020/1b2ynb/c935hvo_0.jpg
#   inflating: Master/IMD2020/1b2ynb/c935hvo_0_mask.png
#   inflating: Master/IMD2020/1b2ynb/c935n1j_0.jpg
#   inflating: Master/IMD2020/1b2ynb/c935n1j_0_mask.png
#   inflating: Master/IMD2020/1b2ynb/c935pb2_0.jpg
#   inflating: Master/IMD2020/1b2ynb/c935pb2_0_mask.png
#   inflating: Master/IMD2020/1b2ynb/c936lfy_0.jpg
#   inflating: Master/IMD2020/1b2ynb/c936lfy_0_mask.png
#   inflating: Master/IMD2020/1b2ynb/c936xo5_0.png
#   inflating: Master/IMD2020/1b2ynb/c936xo5_0_mask.png
#   inflating: Master/IMD2020/1b2ynb/c938omt_0.png
#   inflating: Master/IMD2020/1b2ynb/c938omt_0_mask.png
#    creating: Master/IMD2020/1b3t1x/
#   inflating: Master/IMD2020/1b3t1x/1b3t1x_orig.jpg
#   inflating: Master/IMD2020/1b3t1x/c93czl5_0.jpg
#   inflating: Master/IMD2020/1b3t1x/c93czl5_0_mask.png
#    creating: Master/IMD2020/1b4a9x/
#   inflating: Master/IMD2020/1b4a9x/1b4a9x_orig.jpg
#   inflating: Master/IMD2020/1b4a9x/c93hbzp_0.png
#   inflating: Master/IMD2020/1b4a9x/c93hbzp_0_mask.png
#   inflating: Master/IMD2020/1b4a9x/c93hwyp_0.jpg
#   inflating: Master/IMD2020/1b4a9x/c93hwyp_0_mask.png
#   inflating: Master/IMD2020/1b4a9x/c93idi8_0.jpg
#   inflating: Master/IMD2020/1b4a9x/c93idi8_0_mask.png
#   inflating: Master/IMD2020/1b4a9x/c93ls41_0.jpg
#   inflating: Master/IMD2020/1b4a9x/c93ls41_0_mask.png
#   inflating: Master/IMD2020/1b4a9x/c93me8y_0.png
#   inflating: Master/IMD2020/1b4a9x/c93me8y_0_mask.png
#   inflating: Master/IMD2020/1b4a9x/c93mz9d_0.jpg
#   inflating: Master/IMD2020/1b4a9x/c93mz9d_0_mask.png
#    creating: Master/IMD2020/1b4knn/
#   inflating: Master/IMD2020/1b4knn/1b4knn_orig.jpg
#   inflating: Master/IMD2020/1b4knn/c93k770_0.jpg
#   inflating: Master/IMD2020/1b4knn/c93k770_0_mask.png
#   inflating: Master/IMD2020/1b4knn/c93kbyf_0.jpg
#   inflating: Master/IMD2020/1b4knn/c93kbyf_0_mask.png
#    creating: Master/IMD2020/1b6yyc/
#   inflating: Master/IMD2020/1b6yyc/1b6yyc_orig.jpg
#   inflating: Master/IMD2020/1b6yyc/c9482ja_0.jpg
#   inflating: Master/IMD2020/1b6yyc/c9482ja_0_mask.png
#   inflating: Master/IMD2020/1b6yyc/c948lks_0.jpg
#   inflating: Master/IMD2020/1b6yyc/c948lks_0_mask.png
#   inflating: Master/IMD2020/1b6yyc/c949b58_0.jpg
#   inflating: Master/IMD2020/1b6yyc/c949b58_0_mask.png
#   inflating: Master/IMD2020/1b6yyc/c949vtj_0.png
#   inflating: Master/IMD2020/1b6yyc/c949vtj_0_mask.png
#   inflating: Master/IMD2020/1b6yyc/c949wvr_0.jpg
#   inflating: Master/IMD2020/1b6yyc/c949wvr_0_mask.png
#   inflating: Master/IMD2020/1b6yyc/c949yvb_0.jpg
#   inflating: Master/IMD2020/1b6yyc/c949yvb_0_mask.png
#   inflating: Master/IMD2020/1b6yyc/c94b087_0.jpg
#   inflating: Master/IMD2020/1b6yyc/c94b087_0_mask.png
#   inflating: Master/IMD2020/1b6yyc/c94bbxr_0.jpg
#   inflating: Master/IMD2020/1b6yyc/c94bbxr_0_mask.png
#   inflating: Master/IMD2020/1b6yyc/c94cpfe_0.jpg
#   inflating: Master/IMD2020/1b6yyc/c94cpfe_0_mask.png
#    creating: Master/IMD2020/1b7c47/
#   inflating: Master/IMD2020/1b7c47/1b7c47_orig.jpg
#   inflating: Master/IMD2020/1b7c47/c94a4qa_0.jpg
# ...
#   inflating: Master/IMD2020/1e2gla/c9wcr42_0.jpg
#   inflating: Master/IMD2020/1e2gla/c9wcr42_0_mask.png
#   inflating: Master/IMD2020/1e2gla/c9wf4dc_0.jpg
#   inflating: Master/IMD2020/1e2gla/c9wf4dc_0_mask.png
#    creating: Master/IMD2020/1e2ic4/
#   inflating: Master/IMD2020/1e2ic4/1e2ic4_orig.jpg
#   inflating: Master/IMD2020/1e2ic4/c9wa696_0.jpg
#   inflating: Master/IMD2020/1e2ic4/c9wa696_0_mask.png
#    creating: Master/IMD2020/1e2n3i/
#   inflating: Master/IMD2020/1e2n3i/1e2n3i_orig.jpg
#   inflating: Master/IMD2020/1e2n3i/c9w6rkl_0.jpg
#   inflating: Master/IMD2020/1e2n3i/c9w6rkl_0_mask.png
#   inflating: Master/IMD2020/1e2n3i/c9w7716_0.jpg
#   inflating: Master/IMD2020/1e2n3i/c9w7716_0_mask.png
#   inflating: Master/IMD2020/1e2n3i/c9w8w2m_0.jpg
#   inflating: Master/IMD2020/1e2n3i/c9w8w2m_0_mask.png
#   inflating: Master/IMD2020/1e2n3i/c9w96uz_0.jpg
#   inflating: Master/IMD2020/1e2n3i/c9w96uz_0_mask.png
#   inflating: Master/IMD2020/1e2n3i/c9way1w_0.jpg
#   inflating: Master/IMD2020/1e2n3i/c9way1w_0_mask.png
#   inflating: Master/IMD2020/1e2n3i/c9wcfo6_0.jpg
#   inflating: Master/IMD2020/1e2n3i/c9wcfo6_0_mask.png
#   inflating: Master/IMD2020/1e2n3i/c9wi5uo_0.png
#   inflating: Master/IMD2020/1e2n3i/c9wi5uo_0_mask.png
#    creating: Master/IMD2020/1e4fj8/
#   inflating: Master/IMD2020/1e4fj8/1e4fj8_orig.jpg
#   inflating: Master/IMD2020/1e4fj8/c9wp96y_0.jpg
#   inflating: Master/IMD2020/1e4fj8/c9wp96y_0_mask.png
#   inflating: Master/IMD2020/1e4fj8/c9wpjvq_0.jpg
#   inflating: Master/IMD2020/1e4fj8/c9wpjvq_0_mask.png
#   inflating: Master/IMD2020/1e4fj8/c9wpljd_0.jpg
#   inflating: Master/IMD2020/1e4fj8/c9wpljd_0_mask.png
#   inflating: Master/IMD2020/1e4fj8/c9wqghc_0.jpg
#   inflating: Master/IMD2020/1e4fj8/c9wqghc_0_mask.png
#   inflating: Master/IMD2020/1e4fj8/c9wr2m9_0.jpg
#   inflating: Master/IMD2020/1e4fj8/c9wr2m9_0_mask.png
#   inflating: Master/IMD2020/1e4fj8/c9wrd8e_0.jpg
#   inflating: Master/IMD2020/1e4fj8/c9wrd8e_0_mask.png
#   inflating: Master/IMD2020/1e4fj8/c9ws5r0_0.jpg
#   inflating: Master/IMD2020/1e4fj8/c9ws5r0_0_mask.png
#   inflating: Master/IMD2020/1e4fj8/c9wua2z_0.jpg
#   inflating: Master/IMD2020/1e4fj8/c9wua2z_0_mask.png
#   inflating: Master/IMD2020/1e4fj8/c9wwhov_0.jpg
#   inflating: Master/IMD2020/1e4fj8/c9wwhov_0_mask.png
#   inflating: Master/IMD2020/1e4fj8/c9wxubr_0.jpg
#   inflating: Master/IMD2020/1e4fj8/c9wxubr_0_mask.png
#   inflating: Master/IMD2020/1e4fj8/c9wybvp_0.jpg
#   inflating: Master/IMD2020/1e4fj8/c9wybvp_0_mask.png
#    creating: Master/IMD2020/1e5jsy/
#   inflating: Master/IMD2020/1e5jsy/1e5jsy_orig.jpg
#   inflating: Master/IMD2020/1e5jsy/c9x24tr_0.jpg
#   inflating: Master/IMD2020/1e5jsy/c9x24tr_0_mask.png
#   inflating: Master/IMD2020/1e5jsy/c9x67wt_0.jpg
#   inflating: Master/IMD2020/1e5jsy/c9x67wt_0_mask.png
#    creating: Master/IMD2020/1e5ofv/
#   inflating: Master/IMD2020/1e5ofv/1e5ofv_orig.jpg
#   inflating: Master/IMD2020/1e5ofv/c9x7jrj_0.jpg
#   inflating: Master/IMD2020/1e5ofv/c9x7jrj_0_mask.png
#    creating: Master/IMD2020/1e5qxb/
#   inflating: Master/IMD2020/1e5qxb/1e5qxb_orig.jpg
#   inflating: Master/IMD2020/1e5qxb/c9x31z7_0.png
#   inflating: Master/IMD2020/1e5qxb/c9x31z7_0_mask.png
#   inflating: Master/IMD2020/1e5qxb/c9x50xh_0.jpg
#   inflating: Master/IMD2020/1e5qxb/c9x50xh_0_mask.png
#    creating: Master/IMD2020/1e6gw3/
#   inflating: Master/IMD2020/1e6gw3/1e6gw3_orig.jpg
#   inflating: Master/IMD2020/1e6gw3/c9xa55l_0.jpg
#   inflating: Master/IMD2020/1e6gw3/c9xa55l_0_mask.png
#    creating: Master/IMD2020/1e6s35/
#   inflating: Master/IMD2020/1e6s35/1e6s35_orig.jpg
#   inflating: Master/IMD2020/1e6s35/c9xd4rq_0.jpg
#   inflating: Master/IMD2020/1e6s35/c9xd4rq_0_mask.png
#    creating: Master/IMD2020/1e6tmo/
#   inflating: Master/IMD2020/1e6tmo/1e6tmo_orig.jpg
#   inflating: Master/IMD2020/1e6tmo/c9xdfvu_0.jpg
#   inflating: Master/IMD2020/1e6tmo/c9xdfvu_0_mask.png
#   inflating: Master/IMD2020/1e6tmo/c9xdmhf_0.jpg
#   inflating: Master/IMD2020/1e6tmo/c9xdmhf_0_mask.png
#   inflating: Master/IMD2020/1e6tmo/c9xdp5v_0.jpg
#   inflating: Master/IMD2020/1e6tmo/c9xdp5v_0_mask.png
#   inflating: Master/IMD2020/1e6tmo/c9xdu1a_0.png
#   inflating: Master/IMD2020/1e6tmo/c9xdu1a_0_mask.png
#   inflating: Master/IMD2020/1e6tmo/c9xe80s_0.jpg
#   inflating: Master/IMD2020/1e6tmo/c9xe80s_0_mask.png
#   inflating: Master/IMD2020/1e6tmo/c9xegom_0.png
#   inflating: Master/IMD2020/1e6tmo/c9xegom_0_mask.png
#   inflating: Master/IMD2020/1e6tmo/c9xfdz5_0.jpg
#   inflating: Master/IMD2020/1e6tmo/c9xfdz5_0_mask.png
#   inflating: Master/IMD2020/1e6tmo/c9xfmme_0.jpg
#   inflating: Master/IMD2020/1e6tmo/c9xfmme_0_mask.png
#   inflating: Master/IMD2020/1e6tmo/c9xfzri_0.jpg
#   inflating: Master/IMD2020/1e6tmo/c9xfzri_0_mask.png
#   inflating: Master/IMD2020/1e6tmo/c9xhn4w_0.jpg
#   inflating: Master/IMD2020/1e6tmo/c9xhn4w_0_mask.png
#   inflating: Master/IMD2020/1e6tmo/c9xi6ts_0.jpg
#   inflating: Master/IMD2020/1e6tmo/c9xi6ts_0_mask.png
#   inflating: Master/IMD2020/1e6tmo/c9xl2zu_0.jpg
#   inflating: Master/IMD2020/1e6tmo/c9xl2zu_0_mask.png
#   inflating: Master/IMD2020/1e6tmo/c9xo089_0.jpg
#   inflating: Master/IMD2020/1e6tmo/c9xo089_0_mask.png
#    creating: Master/IMD2020/1e6vy8/
#   inflating: Master/IMD2020/1e6vy8/1e6vy8_orig.jpg
#   inflating: Master/IMD2020/1e6vy8/c9xgn8b_0.jpg
#   inflating: Master/IMD2020/1e6vy8/c9xgn8b_0_mask.png
#    creating: Master/IMD2020/1e7hp5/
#   inflating: Master/IMD2020/1e7hp5/1e7hp5_orig.jpg
#   inflating: Master/IMD2020/1e7hp5/c9xkpkx_0.jpg
#   inflating: Master/IMD2020/1e7hp5/c9xkpkx_0_mask.png
#    creating: Master/IMD2020/1e8iwm/
#   inflating: Master/IMD2020/1e8iwm/1e8iwm_orig.jpg
#   inflating: Master/IMD2020/1e8iwm/c9xt8lv_0.jpg
#   inflating: Master/IMD2020/1e8iwm/c9xt8lv_0_mask.png
#   inflating: Master/IMD2020/1e8iwm/c9xup2p_0.png
#   inflating: Master/IMD2020/1e8iwm/c9xup2p_0_mask.png
#   inflating: Master/IMD2020/1e8iwm/c9xuxck_0.jpg
#   inflating: Master/IMD2020/1e8iwm/c9xuxck_0_mask.png
#   inflating: Master/IMD2020/1e8iwm/c9xv7da_0.jpg
#   inflating: Master/IMD2020/1e8iwm/c9xv7da_0_mask.png
#   inflating: Master/IMD2020/1e8iwm/c9xwa8e_0.jpg
#   inflating: Master/IMD2020/1e8iwm/c9xwa8e_0_mask.png
#    creating: Master/IMD2020/1ch2bt/
#   inflating: Master/IMD2020/1ch2bt/1ch2bt_orig.jpg
#   inflating: Master/IMD2020/1ch2bt/c9ggl99_0.jpg
#   inflating: Master/IMD2020/1ch2bt/c9ggl99_0_mask.png
#   inflating: Master/IMD2020/1ch2bt/c9gmqwd_0.png
#   inflating: Master/IMD2020/1ch2bt/c9gmqwd_0_mask.png
#   inflating: Master/IMD2020/1ch2bt/c9gn0vx_0.jpg
#   inflating: Master/IMD2020/1ch2bt/c9gn0vx_0_mask.png
#    creating: Master/IMD2020/1chfs0/
#   inflating: Master/IMD2020/1chfs0/1chfs0_orig.jpg
#   inflating: Master/IMD2020/1chfs0/c9gjago_0.jpg
#   inflating: Master/IMD2020/1chfs0/c9gjago_0_mask.png
#   inflating: Master/IMD2020/1chfs0/c9gl75j_0.jpg
#   inflating: Master/IMD2020/1chfs0/c9gl75j_0_mask.png
#   inflating: Master/IMD2020/1chfs0/c9glbxq_0.jpg
#   inflating: Master/IMD2020/1chfs0/c9glbxq_0_mask.png
#   inflating: Master/IMD2020/1chfs0/c9grcz4_0.jpg
#   inflating: Master/IMD2020/1chfs0/c9grcz4_0_mask.png
#   inflating: Master/IMD2020/1chfs0/c9gss1i_0.jpg
#   inflating: Master/IMD2020/1chfs0/c9gss1i_0_mask.png
#   inflating: Master/IMD2020/1chfs0/c9gtq1e_0.jpg
#   inflating: Master/IMD2020/1chfs0/c9gtq1e_0_mask.png
#    creating: Master/IMD2020/1chs2a/
#   inflating: Master/IMD2020/1chs2a/1chs2a_orig.jpg
#   inflating: Master/IMD2020/1chs2a/c9grv2t_0.jpg
#   inflating: Master/IMD2020/1chs2a/c9grv2t_0_mask.png
#   inflating: Master/IMD2020/1chs2a/c9gs7bm_0.png
#   inflating: Master/IMD2020/1chs2a/c9gs7bm_0_mask.png
#   inflating: Master/IMD2020/1chs2a/c9gsyda_0.jpg
#   inflating: Master/IMD2020/1chs2a/c9gsyda_0_mask.png
#   inflating: Master/IMD2020/1chs2a/c9gtkcd_0.jpg
#   inflating: Master/IMD2020/1chs2a/c9gtkcd_0_mask.png
#   inflating: Master/IMD2020/1chs2a/c9gtlnu_0.jpg
#   inflating: Master/IMD2020/1chs2a/c9gtlnu_0_mask.png
#   inflating: Master/IMD2020/1chs2a/c9gw35r_0.jpg
#   inflating: Master/IMD2020/1chs2a/c9gw35r_0_mask.png
#    creating: Master/IMD2020/1chuq3/
#   inflating: Master/IMD2020/1chuq3/1chuq3_orig.jpg
#   inflating: Master/IMD2020/1chuq3/c9gmtbg_0.jpg
#   inflating: Master/IMD2020/1chuq3/c9gmtbg_0_mask.png
#   inflating: Master/IMD2020/1chuq3/c9gn94z_0.jpg
#   inflating: Master/IMD2020/1chuq3/c9gn94z_0_mask.png
#    creating: Master/IMD2020/z2/
#   inflating: Master/IMD2020/z2/00006_fake.jpg
#   inflating: Master/IMD2020/z2/00006_fake_mask.png
#   inflating: Master/IMD2020/z2/00006_orig.jpg
#    creating: Master/IMD2020/z3/
#   inflating: Master/IMD2020/z3/00009_fake.jpg
#   inflating: Master/IMD2020/z3/00009_fake_mask.png
#   inflating: Master/IMD2020/z3/00009_orig.jpg
#    creating: Master/IMD2020/z4/
#   inflating: Master/IMD2020/z4/00010_fake_01.jpg
#   inflating: Master/IMD2020/z4/00010_fake_01_mask.png
#   inflating: Master/IMD2020/z4/00010_fake_02.png
#   inflating: Master/IMD2020/z4/00010_fake_02_mask.png
#   inflating: Master/IMD2020/z4/00010_orig.jpg
#    creating: Master/IMD2020/z5/
#   inflating: Master/IMD2020/z5/00022_fake.jpg
#   inflating: Master/IMD2020/z5/00022_fake_mask.png
#   inflating: Master/IMD2020/z5/00022_orig.jpg
#    creating: Master/IMD2020/z6/
#   inflating: Master/IMD2020/z6/00011_fake.jpg
#   inflating: Master/IMD2020/z6/00011_fake_mask.png
#   inflating: Master/IMD2020/z6/00011_orig.jpg
#    creating: Master/IMD2020/z7/
#   inflating: Master/IMD2020/z7/00015_fake.jpg
#   inflating: Master/IMD2020/z7/00015_fake_mask.png
#   inflating: Master/IMD2020/z7/00015_orig.jpg
#    creating: Master/IMD2020/z8/
#   inflating: Master/IMD2020/z8/00016_fake.jpg
#   inflating: Master/IMD2020/z8/00016_fake_mask.png
#   inflating: Master/IMD2020/z8/00016_orig.jpg
#    creating: Master/IMD2020/z9/
#   inflating: Master/IMD2020/z9/00018_fake.jpg
#   inflating: Master/IMD2020/z9/00018_fake_mask.png
#   inflating: Master/IMD2020/z9/00018_orig.jpg
#    creating: Master/IMD2020/z10/
#   inflating: Master/IMD2020/z10/00021_fake.jpg
#   inflating: Master/IMD2020/z10/00021_fake_mask.png
#   inflating: Master/IMD2020/z10/00021_orig.jpg
#    creating: Master/IMD2020/z11/
#   inflating: Master/IMD2020/z11/00024_fake.jpg
#   inflating: Master/IMD2020/z11/00024_fake_mask.png
#   inflating: Master/IMD2020/z11/00024_orig.jpg
#    creating: Master/IMD2020/z12/
#   inflating: Master/IMD2020/z12/00027_fake.jpg
#   inflating: Master/IMD2020/z12/00027_fake_mask.png
#   inflating: Master/IMD2020/z12/00027_orig.jpg
#    creating: Master/IMD2020/z13/
#   inflating: Master/IMD2020/z13/00028_fake.jpg
#   inflating: Master/IMD2020/z13/00028_fake_mask.png
#   inflating: Master/IMD2020/z13/00028_orig.jpg
#    creating: Master/IMD2020/z14/
#   inflating: Master/IMD2020/z14/00030_fake.jpg
#   inflating: Master/IMD2020/z14/00030_fake_mask.png
#   inflating: Master/IMD2020/z14/00030_orig.jpg
#    creating: Master/IMD2020/z15/
#   inflating: Master/IMD2020/z15/00031_fake.jpg
#   inflating: Master/IMD2020/z15/00031_fake_mask.png
#   inflating: Master/IMD2020/z15/00031_orig.jpg
#    creating: Master/IMD2020/z16/
#   inflating: Master/IMD2020/z16/00032_fake.jpg
#   inflating: Master/IMD2020/z16/00032_fake_mask.png
#   inflating: Master/IMD2020/z16/00032_orig.jpg
#    creating: Master/IMD2020/z17/
#   inflating: Master/IMD2020/z17/00035_fake.jpg
#   inflating: Master/IMD2020/z17/00035_fake_mask.png
#   inflating: Master/IMD2020/z17/00035_orig.jpg
#    creating: Master/IMD2020/z18/
#   inflating: Master/IMD2020/z18/00036_fake.jpg
#   inflating: Master/IMD2020/z18/00036_fake_mask.png
#   inflating: Master/IMD2020/z18/00036_orig.jpg
#    creating: Master/IMD2020/z19/
#   inflating: Master/IMD2020/z19/00037_fake.jpg
#   inflating: Master/IMD2020/z19/00037_fake_mask.png
#   inflating: Master/IMD2020/z19/00037_orig.jpg
#    creating: Master/IMD2020/z20/
#   inflating: Master/IMD2020/z20/00041_fake.jpg
#   inflating: Master/IMD2020/z20/00041_fake_mask.png
#   inflating: Master/IMD2020/z20/00041_orig.jpg
#    creating: Master/IMD2020/z21/
#   inflating: Master/IMD2020/z21/00044_fake.jpg
#   inflating: Master/IMD2020/z21/00044_fake_mask.png
#   inflating: Master/IMD2020/z21/00044_orig.jpg
#    creating: Master/IMD2020/z22/
#   inflating: Master/IMD2020/z22/00047_fake_01.jpg
#   inflating: Master/IMD2020/z22/00047_fake_01_mask.png
#   inflating: Master/IMD2020/z22/00047_fake_02.jpg
#   inflating: Master/IMD2020/z22/00047_fake_02_mask.png
#   inflating: Master/IMD2020/z22/00047_orig.jpg
#    creating: Master/IMD2020/z23/
#   inflating: Master/IMD2020/z23/00050_fake.jpg
#   inflating: Master/IMD2020/z23/00050_fake_mask.png
#   inflating: Master/IMD2020/z23/00050_orig.jpg
#    creating: Master/IMD2020/z24/
#   inflating: Master/IMD2020/z24/00056_fake.jpg
#   inflating: Master/IMD2020/z24/00056_fake_mask.png
#   inflating: Master/IMD2020/z24/00056_orig.jpg
#    creating: Master/IMD2020/z25/
#   inflating: Master/IMD2020/z25/00057_fake.jpg
#   inflating: Master/IMD2020/z25/00057_fake_mask.png
#   inflating: Master/IMD2020/z25/00057_orig.jpg
#    creating: Master/IMD2020/z26/
#   inflating: Master/IMD2020/z26/00059_fake.jpg
#   inflating: Master/IMD2020/z26/00059_fake_mask.png
#   inflating: Master/IMD2020/z26/00059_orig.jpg
#    creating: Master/IMD2020/z27/
#   inflating: Master/IMD2020/z27/00064_fake.jpg
#   inflating: Master/IMD2020/z27/00064_fake_mask.png
#   inflating: Master/IMD2020/z27/00064_orig.jpg
#    creating: Master/IMD2020/z28/
#   inflating: Master/IMD2020/z28/00065_fake.jpg
#   inflating: Master/IMD2020/z28/00065_fake_mask.png
#   inflating: Master/IMD2020/z28/00065_orig.jpg
#    creating: Master/IMD2020/z29/
#   inflating: Master/IMD2020/z29/00073_fake.jpg
#   inflating: Master/IMD2020/z29/00073_fake_mask.png
#   inflating: Master/IMD2020/z29/00073_orig.jpg
#    creating: Master/IMD2020/z30/
#   inflating: Master/IMD2020/z30/00076_fake.jpg
#   inflating: Master/IMD2020/z30/00076_fake_mask.png
#   inflating: Master/IMD2020/z30/00076_orig.jpg
#    creating: Master/IMD2020/z31/
#   inflating: Master/IMD2020/z31/00079_fake.jpg
#   inflating: Master/IMD2020/z31/00079_fake_mask.png
#   inflating: Master/IMD2020/z31/00079_orig.jpg
#    creating: Master/IMD2020/z32/
#   inflating: Master/IMD2020/z32/00087_fake.jpg
#   inflating: Master/IMD2020/z32/00087_fake_mask.png
#   inflating: Master/IMD2020/z32/00087_orig.jpg
#    creating: Master/IMD2020/z33/
#   inflating: Master/IMD2020/z33/00088_fake.jpg
#   inflating: Master/IMD2020/z33/00088_fake_mask.png
#   inflating: Master/IMD2020/z33/00088_orig.jpg
#    creating: Master/IMD2020/z34/
#   inflating: Master/IMD2020/z34/00089_fake.jpg
#   inflating: Master/IMD2020/z34/00089_fake_mask.png
#   inflating: Master/IMD2020/z34/00089_orig.jpg
#    creating: Master/IMD2020/z35/
#   inflating: Master/IMD2020/z35/00090_fake.jpg
#   inflating: Master/IMD2020/z35/00090_fake_mask.png
#   inflating: Master/IMD2020/z35/00090_orig.jpg
#    creating: Master/IMD2020/z36/
#   inflating: Master/IMD2020/z36/00095_fake.jpg
#   inflating: Master/IMD2020/z36/00095_fake_mask.png
#   inflating: Master/IMD2020/z36/00095_orig.jpg
#    creating: Master/IMD2020/z37/
#   inflating: Master/IMD2020/z37/00097_fake.jpg
#   inflating: Master/IMD2020/z37/00097_fake_mask.png
#   inflating: Master/IMD2020/z37/00097_orig.jpg
#    creating: Master/IMD2020/z38/
#   inflating: Master/IMD2020/z38/00099_fake.jpg
#   inflating: Master/IMD2020/z38/00099_fake_mask.png
#   inflating: Master/IMD2020/z38/00099_orig.jpg
#    creating: Master/IMD2020/z39/
#   inflating: Master/IMD2020/z39/00104_fake.jpg
#   inflating: Master/IMD2020/z39/00104_fake_mask.png
#   inflating: Master/IMD2020/z39/00104_orig.jpg
#    creating: Master/IMD2020/z40/
#   inflating: Master/IMD2020/z40/00107_fake.jpg
#   inflating: Master/IMD2020/z40/00107_fake_mask.png
#   inflating: Master/IMD2020/z40/00107_orig.jpg
#    creating: Master/IMD2020/z41/
#   inflating: Master/IMD2020/z41/00109_fake.jpg
#   inflating: Master/IMD2020/z41/00109_fake_mask.png
#   inflating: Master/IMD2020/z41/00109_orig.jpg

# %%
# !unzip /content/Master/annotations/panoptic_val2017.zip -d Master
# !mv /content/Master/annotations/panoptic_val2017.json /content/Master # move src dest
# !mv /content/Master/instances/annotations/instances_val2017.json /content/Master # move src dest
# # !unzip /content/Master/panoptic_annotations_trainval2017.zip -d Master

# !rm -r /content/Master/IMD2020/IMD2020.zip

# !unzip /content/Master/annotations/panoptic_train2017.zip -d Master
# !mv /content/Master/annotations/panoptic_train2017.json /content/Master # move src dest
# !mv /content/Master/instances/annotations/instances_train2017.json /content/Master # move src dest

# %%
# import shutil

# shutil.rmtree('/content/Master', ignore_errors=True)

# %% [markdown]
# # Libraries

# %%
# For managing COCO dataset
# from pycocotools.coco import COCO

# For creating and managing folder/ files
import glob
import os
import shutil

# For managing images
from PIL import Image
import skimage.io as io

# Basic libraries
import numpy as np
import pandas as pd
import random
import cv2

# For plotting
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns

# For importing models and working with them
## Torch
import torch
import torch.utils.data # for Dataset
import torch.nn as nn
from torch.optim import Adam
from torch.autograd import Variable
from torch.utils.data import DataLoader, Dataset

## Torchvision
import torchvision
from torchvision.transforms import transforms

# For creating train - test splits
from sklearn.model_selection import train_test_split

import pathlib
import pylab
import requests
from io import BytesIO
from pprint import pprint
from tqdm import tqdm
import time
from imutils import paths

# Performance Metrics
from sklearn.metrics import multilabel_confusion_matrix


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)


# %matplotlib inline
# Out:
# cuda

# %% [markdown]
# # Configuration

# %%
# data = 'train2017'

# # Data and Masks
# IMAGE_PATH = os.path.join('/content/Master/', data)
# MASK_PATH = os.path.join('/content/Master/', 'panoptic_' + data)

# # define the path to the base output directory
# BASE_OUTPUT = '/content/Master/Output'

# # define the path to the output serialized model, model training plot, and testing image paths
# MODEL_PATH = os.path.join(BASE_OUTPUT, "unet_tgs_salt.pth")
# PLOT_PATH = os.path.sep.join([BASE_OUTPUT, "plot.png"])
# TEST_PATHS = os.path.sep.join([BASE_OUTPUT, "test_paths.txt"])



# # determine if we will be pinning memory during data loading
# PIN_MEMORY = True if device == "cuda" else False


# # define the number of channels in the input, number of classes, and number of levels in the U-Net model
# # NUM_CHANNELS = 3
# # NUM_CLASSES = 2 # person vs Background

# # define the input image dimensions
# INPUT_IMAGE_WIDTH = 256
# INPUT_IMAGE_HEIGHT = 256

# # define threshold to filter weak predictions
# THRESHOLD = 0.5 # for binary classification

# %% [markdown]
# # Functions

# %%
def gen_binary_mask (img, coco, anns):
  mask = np.zeros((img['height'], img['width']))

  for i in range(len(anns)):

      mask = np.maximum(mask, coco.annToMask(anns[i]) * anns[i]['category_id'] )

  return mask

# %%
def calculate_metrics(gt_masks, pred_masks):
    tp = 0  # true positive
    tn = 0  # true negative
    fp = 0  # false positive
    fn = 0  # false negative

    for gt_mask, pred_mask in zip(gt_masks, pred_masks):
        gt_mask = gt_mask.flatten()
        pred_mask = pred_mask.flatten()

        tp += np.sum(np.logical_and(pred_mask == 1, gt_mask == 1))
        tn += np.sum(np.logical_and(pred_mask == 0, gt_mask == 0))
        fp += np.sum(np.logical_and(pred_mask == 1, gt_mask == 0))
        fn += np.sum(np.logical_and(pred_mask == 0, gt_mask == 1))

    accuracy = (tp + tn) / (tp + tn + fp + fn)
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    f1_score = 2 * (precision * recall) / (precision + recall)

    return accuracy, precision, recall, f1_score

# %%
def calculate_dice_coefficient(gt_masks, pred_masks):
    intersection = np.logical_and(gt_masks, pred_masks)
    dice_coefficient = (2.0 * intersection.sum()) / (gt_masks.sum() + pred_masks.sum())
    return dice_coefficient

def calculate_iou(gt_masks, pred_masks):
    intersection = np.logical_and(gt_masks, pred_masks)
    union = np.logical_or(gt_masks, pred_masks)
    iou = intersection.sum() / union.sum()
    return iou

# %%
def train_model(model, dataloader, steps, loss_function, optim, device):
  print("Training...")

  model.train()

  totalTrainLoss = 0

  # loop over the training set
  for i, (x, y) in enumerate(dataloader):

      # send the input to the device
      (x, y) = (x.to(device), y.to(device))

      # perform a forward pass and calculate the training loss
      pred = model(x)
      loss = loss_function(pred, y)

      # first, zero out any previously accumulated gradients, then
      # perform backpropagation, and then update model parameters
      optim.zero_grad()
      loss.backward()
      optim.step()

      # add the loss to the total training loss so far
      totalTrainLoss += loss


  avgTrainLoss = totalTrainLoss / steps

  return avgTrainLoss

# %%
def validate_model(model, dataloader, steps, loss_function, optim, device):
  print("Validating...")

  model.eval()

  totalTrainLoss = 0

  # loop over the training set
  with torch.no_grad():
    for i, (x, y) in enumerate(dataloader):

        # send the input to the device
        (x, y) = (x.to(device), y.to(device))

        # perform a forward pass and calculate the training loss
        pred = model(x)
        loss = loss_function(pred, y)

        # add the loss to the total training loss so far
        totalTrainLoss += loss


    avgTrainLoss = totalTrainLoss / steps

    return avgTrainLoss

# %% [markdown]
# ## Dataset

# %%
class SegmentationDataset(Dataset):

    def __init__(self, imagePaths, maskPaths, transforms):
        # store the image and mask filepaths, and augmentation transforms
        self.imagePaths = imagePaths
        self.maskPaths = maskPaths
        self.transforms = transforms


    def __len__(self):
        # return the number of total samples contained in the dataset
        return len(self.imagePaths)


    def __getitem__(self, idx):

        image = Image.open(self.imagePaths[idx]).convert("RGB")
        mask = Image.open(self.maskPaths[idx]).convert("L")

        if self.transforms is not None:
            image = self.transforms(image)
            mask = self.transforms(mask)


        # return a tuple of the image and its mask
        return (image, mask)

# %% [markdown]
# # Data

# %% [markdown]
# ## Data Preparation

# %%
from torch.utils.data import Dataset
from PIL import Image

class SegmentationDataset(Dataset):

    def __init__(self, original_images, altered_images, masks, transforms=None):
        self.original_images = original_images
        self.altered_images = altered_images
        self.masks = masks
        self.transforms = transforms

    def __len__(self):
        return len(self.original_images)

    def __getitem__(self, idx):
        original_image = self.original_images[idx]
        altered_image = self.altered_images[idx]
        mask = self.masks[idx]

        if self.transforms:
            original_image = self.transforms(original_image)
            altered_image = self.transforms(altered_image)
            mask = self.transforms(mask)

        return original_image, altered_image, mask

def load_dataset(dataset_path, num_folders):
    print("Starting loading dataset")
    original_images = []
    altered_images = []
    masks = []

    folders = sorted(os.listdir(dataset_path))[:num_folders]
    for folder in folders:
        folder_path = os.path.join(dataset_path, folder)
        if os.path.isdir(folder_path):
            # Find the common ID from the filenames
            common_id = None
            for file in os.listdir(folder_path):
                if file.endswith('_0.jpg') or file.endswith('_0.png'):
                    common_id = file.split('_')[0]  # Extract common ID from filename
                    break  # Stop after finding the first _0.jpg or _0.png file

            if common_id is None:
                print(f"No altered image found for folder {folder}")
                continue

            # Construct file paths for original image, altered image, and mask
            orig_path = os.path.join(folder_path, folder+'_orig.jpg')
            altered_ext = 'jpg' if os.path.exists(os.path.join(folder_path, common_id+'_0.jpg')) else 'png'
            altered_path = os.path.join(folder_path, common_id+'_0.'+altered_ext)
            mask_path = os.path.join(folder_path, common_id+'_0_mask.png')

            try:
                orig_img = Image.open(orig_path).convert("RGB")
                altered_img = Image.open(altered_path).convert("RGB")
                mask_img = Image.open(mask_path).convert("L")  # Convert to grayscale

                if orig_img is None or altered_img is None or mask_img is None:
                    print(f"Failed to load images for folder {folder}")
                    continue

                original_images.append(orig_img)
                altered_images.append(altered_img)
                masks.append(mask_img)
            except Exception as e:
                print(f"Error loading images for folder {folder}: {e}")

    return original_images, altered_images, masks

# Example usage:
dataset_path = '/content/Master/IMD2020'
num_folders = 100  # Number of folders to read
original_images, altered_images, masks = load_dataset(dataset_path, num_folders)

# You can apply any transformations needed before creating the dataset
transforms_train = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
])

# Create the dataset
dataset = SegmentationDataset(original_images, altered_images, masks, transforms=transforms_train)
# Out:
# Starting loading dataset

# %%
# dataset.masks[0]

# %%
# import torch
# import matplotlib.pyplot as plt
# import torchvision.transforms.functional as TF

# def visualize_images(original_images, altered_images, masks, pred_masks, num_samples=3, figsize=(15, 15), threshold = 0.4):


#     for i in range(num_samples):
#         plt.figure(figsize=figsize)

#         # orig_rgb = TF.to_pil_image(original_images[i])
#         # altered_rgb = TF.to_pil_image(altered_images[i])

#         # Plot original image
#         plt.subplot(141)
#         plt.imshow(original_images[i].permute(1, 2, 0))
#         plt.title('Original Image')
#         plt.axis('off')

#         # Plot altered image
#         plt.subplot(142)
#         plt.imshow(altered_images[i].permute(1, 2, 0))
#         plt.title('Altered Image')
#         plt.axis('off')

#         # Plot ground truth mask
#         plt.subplot(143)
#         plt.imshow(masks[i][0], cmap='gray')
#         plt.title('Ground Truth Mask')
#         plt.axis('off')

#         # Plot predicted mask (binary)
#         # plt.subplot(144)

#         # flat_pred_masks = pred_masks.flatten()
#         # sorted_values = torch.sort(flat_pred_masks, descending=True).values
#         # tenth_highest_value = sorted_values[9]

#         # binary_pred_mask = (torch.sigmoid(pred_masks[i][0]).cpu() < tenth_highest_value).numpy()

#         # plt.imshow(binary_pred_mask, cmap='gray', vmin=0, vmax=255)
#         # plt.title('Predicted Mask (Binary)')
#         # plt.axis('off')

#         plt.subplot(144)
#         plt.imshow(pred_masks[i][0].detach().cpu().numpy(), cmap='gray')  # Detach and convert to NumPy array
#         plt.title('Predicted Mask')
#         plt.axis('off')

#         # Adjust layout to prevent overlap
#         plt.tight_layout()

#         # Display the plot
#         plt.show()


def calculate_metrics(gt_masks, pred_masks):
    tp = 0  # true positive
    tn = 0  # true negative
    fp = 0  # false positive
    fn = 0  # false negative

    for gt_mask, pred_mask in zip(gt_masks, pred_masks):
        gt_mask = gt_mask.flatten()
        pred_mask = pred_mask.flatten()

        tp += np.sum(np.logical_and(pred_mask == 1, gt_mask == 1))
        tn += np.sum(np.logical_and(pred_mask == 0, gt_mask == 0))
        fp += np.sum(np.logical_and(pred_mask == 1, gt_mask == 0))
        fn += np.sum(np.logical_and(pred_mask == 0, gt_mask == 1))

    accuracy = (tp + tn) / (tp + tn + fp + fn)
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    f1_score = 2 * (precision * recall) / (precision + recall)

    return accuracy, precision, recall, f1_score


def calculate_dice_coefficient(gt_masks, pred_masks):
    intersection = np.logical_and(gt_masks, pred_masks)
    dice_coefficient = (2.0 * intersection.sum()) / (gt_masks.sum() + pred_masks.sum())
    return dice_coefficient

def calculate_iou(gt_masks, pred_masks):
    intersection = np.logical_and(gt_masks, pred_masks)
    union = np.logical_or(gt_masks, pred_masks)
    iou = intersection.sum() / union.sum()
    return iou

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import segmentation_models_pytorch as smp
import time
from tqdm import tqdm
import matplotlib.pyplot as plt
import wandb

wandb.login()

# Define device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Initialize the U-Net model
unet = smp.Unet(
    encoder_name="resnet101",
    encoder_weights="imagenet",
    in_channels=3,  # Assuming 3 channels for both original and altered images
    classes=1  # Output classes (1 for mask)
).to(device)

# Define hyperparameters
INIT_LR = 0.0001
BATCH_SIZE = 16
NUM_EPOCHS = [10, 20, 50, 100, 150]
TEST_SPLIT = [0.3]
VALID_SPLIT = 0.1

# Initialize loss function and optimizer
lossFunc = nn.BCEWithLogitsLoss()
opt = torch.optim.Adam(unet.parameters(), lr=INIT_LR)

# Define transformations for test (optional)
transforms_test = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
])

# Create DataLoader for the dataset
trainLoader = DataLoader(dataset, shuffle=True, batch_size=BATCH_SIZE)
print("Dataset length:", len(trainLoader.dataset))

# Calculate steps per epoch for training set
trainSteps = len(trainLoader)

for tts in TEST_SPLIT:
    print("[INFO] TEST_SPLIT = {} ...".format(tts))

    print("Splits, Datasets, and Dataloaders")
    startTime = time.time()

    train_orig_images, test_orig_images, train_altered_images, test_altered_images, train_masks, test_masks = train_test_split(original_images, altered_images, masks, test_size=TEST_SPLIT, random_state=42)
    train_orig_images, val_orig_images, train_altered_images, val_altered_images, train_masks, val_masks = train_test_split(train_orig_images, train_altered_images, train_masks, test_size=VALID_SPLIT, random_state=42)

    # Create datasets and data loaders for training, validation, and testing sets
    train_dataset = SegmentationDataset(train_orig_images, train_altered_images, train_masks, transforms=transforms_train)
    val_dataset = SegmentationDataset(val_orig_images, val_altered_images, val_masks, transforms=transforms_test)
    test_dataset = SegmentationDataset(test_orig_images, test_altered_images, test_masks, transforms=transforms_test)

    train_loader = DataLoader(train_dataset, shuffle=True, batch_size=BATCH_SIZE)
    val_loader = DataLoader(val_dataset, shuffle=False, batch_size=BATCH_SIZE)
    test_loader = DataLoader(test_dataset, shuffle=False, batch_size=BATCH_SIZE)


    endTime = time.time()
    print("[INFO] Total time taken to create the dataset and dataloader: {:.2f}s".format(endTime - startTime))

    print(f"[INFO] found {len(dataset)} examples in the training set...")

    # calculate steps per epoch for training set
    trainSteps = len(train_dataset) // BATCH_SIZE
    testSteps = len(test_dataset) // BATCH_SIZE
    valSteps = len(val_dataset) // BATCH_SIZE

    for epoch in NUM_EPOCHS:

        run = wandb.init(
                      # Set the project where this run will be logged
                      project = "my-project",
                      # Track hyperparameters and run metadata
                      config={
                          "learning_rate": INIT_LR,
                          "epochs": epoch,
                          "batch": BATCH_SIZE
                      },
                      )

        # Initialize dictionary to store training history
        H = {"train_loss": []}
        Perf_Metrics = {"accuracy": [], "precision": [], "recall": [], "f1_score": []}
        Dice_IOU = {"dice": [], "iou": []}

        print("[INFO] Training the network for {} epochs...".format(epoch))

        startTime = time.time()

        for e in tqdm(range(epoch)):

            # initialize variables for output
            totalTrainLoss, totalTestLoss, totalValLoss = 0
            accuracy_scores, precision_score, recall_scores, f1_scores = 0, 0, 0, 0
            dice_scores, iou_scores = 0, 0

            # Training loop
            unet.train()
            for orig_images, altered_images, masks in train_loader:
                images, altered_images, masks = images.to(device), altered_images.to(device), masks.to(device)

                opt.zero_grad()
                pred_masks = unet(images) # they are not binary => the binary masks are displayed using the vizualize function with a threshold
                # pred_masks = torch.sigmoid(pred_masks)

                loss = lossFunc(pred_masks, masks)
                loss.backward()
                opt.step()

                pred_masks = (pred_masks > 0.5).float()

                totalTrainLoss += loss.item()

            avg_train_loss = totalTrainLoss / len(train_loader)


            # Validate the model
            unet.eval()
            with torch.no_grad():
                total_val_loss = 0
                for orig_images, altered_images, masks in val_loader:
                    orig_images, altered_images, masks = orig_images.to(device), altered_images.to(device), masks.to(device)
                    pred_masks = unet(orig_images)
                    val_loss = lossFunc(pred_masks, masks)

                    totalValLoss += val_loss.item()

            avg_val_loss = totalValLoss / len(val_loader)

            # Log the losses to WandB
            wandb.log({"train_loss": avg_train_loss, "val_loss": avg_val_loss, "epoch": e})

            unet.eval()
            with torch.no_grad():
                for orig_images, altered_images, masks in test_loader:
                    orig_images, altered_images, masks = orig_images.to(device), altered_images.to(device), masks.to(device)
                    pred_masks = unet(orig_images)


                    # calculate Dice coefficient and IoU score
                    metrics = calculate_metrics(masks.cpu().numpy(), pred_masks.cpu().numpy())
                    accuracy, precision, recall, f1_score = metrics

                    dice_coefficient = calculate_dice_coefficient(masks.cpu().numpy(), pred_masks.cpu().numpy())
                    iou = calculate_iou(masks.cpu().numpy(), pred_masks.cpu().numpy())

                    # avg metrics
                    accuracy_scores += accuracy
                    precision_score += precision
                    recall_scores += recall
                    f1_scores += f1_score

                    dice_scores += dice_coefficient
                    iou_scores += iou


                # visualize_images(images.cpu(), altered_images.cpu(), masks.cpu(), pred_masks.cpu()) #, threshold = tenth_highest_value)

            avgTrainLoss = totalTrainLoss / trainSteps
            avgValLoss = totalValLoss / valSteps
            avgTestLoss = totalTestLoss / testSteps

            # Update training history
            accuracy_scores = accuracy_scores / testSteps #testSteps
            precision_score = precision_score / testSteps
            recall_scores = recall_scores / testSteps
            f1_scores = f1_scores / testSteps

            dice_scores = dice_scores / testSteps
            iou_scores = iou_scores / testSteps

            # update our training history
            H["train_loss"].append(avgTrainLoss)
            H["val_loss"].append(avgValLoss)
            H["test_loss"].append(avgTestLoss)

            # update our performance metrics history
            Perf_Metrics["accuracy"].append(accuracy_scores)
            Perf_Metrics["precision"].append(precision_score)
            Perf_Metrics["recall"].append(recall_scores)
            Perf_Metrics["f1_score"].append(f1_scores)


            # update our dice and IOU score history
            Dice_IOU["dice"].append(dice_scores)
            Dice_IOU["iou"].append(iou_scores)

            # Print training loss
            print("[INFO] EPOCH: {}/{}".format(e + 1, epoch))
            print("Train loss: {:.6f}".format(avgTrainLoss))

            wandb.log({"accuracy": accuracy_scores, "precision": precision_score, "loss": avgTrainLoss})

        # Display total time taken to perform the training
        endTime = time.time()
        print("[INFO] Total time taken to train the model: {:.2f}s".format(endTime - startTime))

        print('\n')

        print("Average accuracy = {}%".format(100 * round(sum(Perf_Metrics["accuracy"])/len(Perf_Metrics["accuracy"]), 2)))
        print("Average precision = {}%".format(100 * round(sum(Perf_Metrics["precision"])/len(Perf_Metrics["precision"]), 2)))
        print("Average recall = {}%".format(100 * round(sum(Perf_Metrics["recall"])/len(Perf_Metrics["recall"]), 2)))
        print("Average f1_score = {}%".format(100 * round(sum(Perf_Metrics["accuracy"])/len(Perf_Metrics["f1_score"]), 2)))

        print("Average DICE = {}%".format(100 * round(sum(Dice_IOU["dice"])/len(Dice_IOU["dice"]), 2)))
        print("Average IOU = {}%".format(100 * round(sum(Dice_IOU["iou"])/len(Dice_IOU["iou"]), 2)))

        print('\n')


        lent = images.cpu().numpy().shape[0]

        for i in range (0, lent):
          plt.figure(figsize = (12, 12))

          # plot original image
          plt.subplot(141)
          plt.imshow(images.cpu().numpy()[i].transpose(1, 2, 0))
          plt.title('Original Image')
          plt.axis('off')

          # plot ground truth mask
          plt.subplot(142)
          plt.imshow(altered_images.cpu().numpy()[i][0])
          plt.title('Altered Image')
          plt.axis('off')

          # plot predicted mask
          plt.subplot(143)
          plt.imshow(masks.cpu().numpy()[i][0], cmap='gray')
          plt.title('Ground Truth Mask')
          plt.axis('off')

          # plot predicted mask
          plt.subplot(144)
          plt.imshow(pred_masks.cpu().numpy()[i][0], cmap='gray')
          plt.title('Predicted Mask')
          plt.axis('off')

          # display the plot
          plt.show()


        # plot the training loss
        plt.style.use("ggplot")
        plt.figure()
        plt.plot(H["train_loss"], label = "train_loss")
        # plt.plot(H["val_loss"], label="val_loss")
        # plt.plot(H["test_loss"], label="test_loss")
        plt.title("Training, Validation and Test Loss on Dataset")
        plt.xlabel("Epoch #")
        plt.ylabel("Loss")
        plt.legend()
        plt.show()


        ##### NOT FOR NOW ######
        # plot the performance metrics
        # plt.style.use("ggplot")
        # plt.figure()
        # plt.plot(Perf_Metrics["accuracy"], label = "accuracy")
        # plt.plot(Perf_Metrics["precision"], label="precision")
        # plt.plot(Perf_Metrics["recall"], label="recall")
        # plt.plot(Perf_Metrics["f1_score"], label="f1_score")

        # plt.title("Segmentation Performance Metrics")
        # plt.xlabel("Epoch #")
        # plt.ylabel("Metrics")
        # plt.legend()
        # plt.show()


        # # plot the performance metrics
        # plt.style.use("ggplot")
        # plt.figure()
        # plt.plot(Dice_IOU["dice"], label = "DICE")
        # plt.plot(Dice_IOU["iou"], label="IOU")

        # plt.title("Segmentation Performance Metrics")
        # plt.xlabel("Epoch #")
        # plt.ylabel("Segmentation Metrics")
        # plt.legend()
        # plt.show()

        print('\n')
# Out:
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# Dataset length: 100
# [INFO] TEST_SPLIT = 0.3 ...
# Splits, Datasets, and Dataloaders
# [INFO] Total time taken to create the dataset and dataloader: 0.00s
# [INFO] found 100 examples in the training set...
# Finishing last run (ID:j4sz5ccl) before initializing another...
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▄▆▆▇▇████</td></tr><tr><td>loss</td><td>▁▂▃▄▅▅▆▇▇█</td></tr><tr><td>precision</td><td>▁▂▄▅▆▇▇▇██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>1.11057</td></tr><tr><td>loss</td><td>7.00936</td></tr><tr><td>precision</td><td>0.99835</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">breezy-music-5</strong> at: <a href='https://wandb.ai/bianca-team/my-project/runs/j4sz5ccl/workspace' target="_blank">https://wandb.ai/bianca-team/my-project/runs/j4sz5ccl/workspace</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240327_001826-j4sz5ccl/logs</code>
# Successfully finished last run (ID:j4sz5ccl). Initializing new run:<br/>
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>/content/wandb/run-20240327_002119-xnq4oyxo</code>
# Syncing run <strong><a href='https://wandb.ai/bianca-team/my-project/runs/xnq4oyxo/workspace' target="_blank">fragrant-salad-6</a></strong> to <a href='https://wandb.ai/bianca-team/my-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/bianca-team/my-project' target="_blank">https://wandb.ai/bianca-team/my-project</a>
#  View run at <a href='https://wandb.ai/bianca-team/my-project/runs/xnq4oyxo/workspace' target="_blank">https://wandb.ai/bianca-team/my-project/runs/xnq4oyxo/workspace</a>
# [INFO] Training the network for 10 epochs...
#  10%|█         | 1/10 [00:04<00:42,  4.74s/it]
# [INFO] EPOCH: 1/10
# Train loss: 7.627006
#  20%|██        | 2/10 [00:09<00:39,  4.98s/it]
# [INFO] EPOCH: 2/10
# Train loss: 8.182243
#  30%|███       | 3/10 [00:15<00:35,  5.13s/it]
# [INFO] EPOCH: 3/10
# Train loss: 8.672604
#  40%|████      | 4/10 [00:19<00:29,  4.95s/it]
# [INFO] EPOCH: 4/10
# Train loss: 9.111765
#  50%|█████     | 5/10 [00:25<00:25,  5.05s/it]
# [INFO] EPOCH: 5/10
# Train loss: 9.506957
#  60%|██████    | 6/10 [00:29<00:19,  4.93s/it]
# [INFO] EPOCH: 6/10
# Train loss: 9.864156
#  70%|███████   | 7/10 [00:34<00:15,  5.01s/it]
# [INFO] EPOCH: 7/10
# Train loss: 10.215252
#  80%|████████  | 8/10 [00:39<00:09,  4.90s/it]
# [INFO] EPOCH: 8/10
# Train loss: 10.524203
#  90%|█████████ | 9/10 [00:45<00:05,  5.34s/it]
# [INFO] EPOCH: 9/10
# Train loss: 10.809573
# 100%|██████████| 10/10 [00:50<00:00,  5.09s/it]
# [INFO] EPOCH: 10/10
# Train loss: 11.083998
# [INFO] Total time taken to train the model: 50.93s
#
#
# Average accuracy = 109.00000000000001%
# Average precision = 73.0%
# Average recall = 54.0%
# Average f1_score = 109.00000000000001%
# Average DICE = 61.0%
# Average IOU = 43.0%
# Finishing last run (ID:xnq4oyxo) before initializing another...
# VBox(children=(Label(value='0.012 MB of 0.012 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▂▅▆▇▇▇███</td></tr><tr><td>loss</td><td>▁▂▃▄▅▆▆▇▇█</td></tr><tr><td>precision</td><td>▁▂▅▇▇█▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>1.12223</td></tr><tr><td>loss</td><td>11.084</td></tr><tr><td>precision</td><td>0.93609</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fragrant-salad-6</strong> at: <a href='https://wandb.ai/bianca-team/my-project/runs/xnq4oyxo/workspace' target="_blank">https://wandb.ai/bianca-team/my-project/runs/xnq4oyxo/workspace</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240327_002119-xnq4oyxo/logs</code>
# Successfully finished last run (ID:xnq4oyxo). Initializing new run:<br/>
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>/content/wandb/run-20240327_002222-72kfeuhw</code>
# Syncing run <strong><a href='https://wandb.ai/bianca-team/my-project/runs/72kfeuhw/workspace' target="_blank">vocal-elevator-7</a></strong> to <a href='https://wandb.ai/bianca-team/my-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/bianca-team/my-project' target="_blank">https://wandb.ai/bianca-team/my-project</a>
#  View run at <a href='https://wandb.ai/bianca-team/my-project/runs/72kfeuhw/workspace' target="_blank">https://wandb.ai/bianca-team/my-project/runs/72kfeuhw/workspace</a>
# [INFO] Training the network for 20 epochs...
#   5%|▌         | 1/20 [00:04<01:33,  4.94s/it]
# [INFO] EPOCH: 1/20
# Train loss: 11.337129
#  10%|█         | 2/20 [00:10<01:31,  5.11s/it]
# [INFO] EPOCH: 2/20
# Train loss: 11.575116
#  15%|█▌        | 3/20 [00:14<01:23,  4.90s/it]
# [INFO] EPOCH: 3/20
# Train loss: 11.804095
#  20%|██        | 4/20 [00:19<01:18,  4.90s/it]
# [INFO] EPOCH: 4/20
# Train loss: 12.028121
#  25%|██▌       | 5/20 [00:24<01:14,  4.94s/it]
# [INFO] EPOCH: 5/20
# Train loss: 12.247531
#  30%|███       | 6/20 [00:30<01:11,  5.13s/it]
# [INFO] EPOCH: 6/20
# Train loss: 12.455878
#  35%|███▌      | 7/20 [00:38<01:21,  6.29s/it]
# [INFO] EPOCH: 7/20
# Train loss: 12.649061
#  35%|███▌      | 7/20 [00:39<01:14,  5.71s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-100-d530f22317e6> in <cell line: 48>()
#     137                 pred_masks = (pred_masks > 0.5).float()
#     138
# --> 139                 totalTrainLoss += loss.item()
#     140
#     141                 # calculate Dice coefficient and IoU score
#
# KeyboardInterrupt:

# %%
# import torch
# import torch.nn as nn
# from torch.utils.data import DataLoader
# import torchvision.transforms as transforms
# import segmentation_models_pytorch as smp
# import time
# from tqdm import tqdm

# # Define device
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# # Initialize the U-Net model
# unet = smp.Unet(
#     encoder_name="resnet101",
#     encoder_weights="imagenet",
#     in_channels=3,  # Assuming 3 channels for both original and altered images
#     classes=1  # Output classes (1 for mask)
# ).to(device)

# # Define hyperparameters
# INIT_LR = 0.0001
# BATCH_SIZE = 32
# NUM_EPOCHS = [10, 20, 50, 100, 150]
# TEST_SPLIT = [0.3]
# VALID_SPLIT = 0.1

# # Initialize loss function and optimizer
# lossFunc = nn.BCEWithLogitsLoss()
# opt = torch.optim.Adam(unet.parameters(), lr=INIT_LR)

# # Define transformations for test (optional)
# transforms_test = transforms.Compose([
#     transforms.Resize((256, 256)),
#     transforms.ToTensor(),
# ])

# # Create DataLoader for the dataset
# trainLoader = DataLoader(dataset, shuffle=True, batch_size=BATCH_SIZE)

# # Calculate steps per epoch for training set
# trainSteps = len(trainLoader)

# for tts in TEST_SPLIT:
#     print("[INFO] TEST_SPLIT = {} ...".format(tts))

#     print("Splits, Datasets and Dataloaders")
#     startTime = time.time()

#     # Dummy split for testing (using the whole dataset)
#     trainImages = original_images
#     trainAlteredImages = altered_images
#     trainMasks = masks

#     # Create the training dataset
#     trainDS = SegmentationDataset(original_images=trainImages, altered_images=trainAlteredImages, masks=trainMasks, transforms=transforms_train)

#     # Create the training data loader
#     trainLoader = DataLoader(trainDS, shuffle=True, batch_size=BATCH_SIZE)

#     endTime = time.time()
#     print("[INFO] Total time taken to create the dataset and dataloader: {:.2f}s".format(endTime - startTime))

#     print(f"[INFO] found {len(trainDS)} examples in the training set...")

#     # calculate steps per epoch for training set
#     trainSteps = len(trainDS) // BATCH_SIZE

#     for epoch in NUM_EPOCHS:
#         # Initialize dictionary to store training history
#         H = {"train_loss": []}

#         print("[INFO] Training the network for {} epochs...".format(epoch))

#         startTime = time.time()

#         for e in tqdm(range(epoch)):
#             totalTrainLoss = 0

#             # Training loop
#             unet.train()
#             for images, altered_images, masks in trainLoader:
#                 images, altered_images, masks = images.to(device), altered_images.to(device), masks.to(device)

#                 opt.zero_grad()
#                 pred_masks = unet(images)
#                 loss = lossFunc(pred_masks, masks)
#                 loss.backward()
#                 opt.step()

#                 totalTrainLoss += loss.item()

#                 # Visualize images
#                 visualize_images(images.cpu(), altered_images.cpu(), masks.cpu(), torch.sigmoid(pred_masks).cpu())

#             avgTrainLoss = totalTrainLoss / trainSteps

#             # Update training history
#             H["train_loss"].append(avgTrainLoss)

#             # Print training loss
#             print("[INFO] EPOCH: {}/{}".format(e + 1, epoch))
#             print("Train loss: {:.6f}".format(avgTrainLoss))

#         # Display total time taken to perform the training
#         endTime = time.time()
#         print("[INFO] Total time taken to train the model: {:.2f}s".format(endTime - startTime))

#         # Plot training loss
#         plt.plot(H["train_loss"], label="train_loss")
#         plt.title("Training Loss")
#         plt.xlabel("Epoch")
#         plt.ylabel("Loss")
#         plt.legend()
#         plt.show()
# Out:
# [INFO] TEST_SPLIT = 0.3 ...
# Splits, Datasets and Dataloaders
# [INFO] Total time taken to create the dataset and dataloader: 0.00s
# [INFO] found 100 examples in the training set...
# [INFO] Training the network for 10 epochs...
#   0%|          | 0/10 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-aad7311f83c5> in <cell line: 43>()
#      79             # Training loop
#      80             unet.train()
# ---> 81             for images, altered_images, masks in trainLoader:
#      82                 images, altered_images, masks = images.to(device), altered_images.to(device), masks.to(device)
#      83
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     629                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630                 self._reset()  # type: ignore[call-arg]
# --> 631             data = self._next_data()
#     632             self._num_yielded += 1
#     633             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     673     def _next_data(self):
#     674         index = self._next_index()  # may raise StopIteration
# --> 675         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676         if self._pin_memory:
#     677             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# <ipython-input-7-a991be8d80c6> in __getitem__(self, idx)
#      56     def __getitem__(self, idx):
#      57         original_image = self.original_images[idx]
# ---> 58         altered_image = self.altered_images[idx]
#      59         mask = self.masks[idx]
#      60
#
# IndexError: index 55 is out of bounds for dimension 0 with size 32
